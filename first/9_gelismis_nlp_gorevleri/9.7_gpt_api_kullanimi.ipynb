# %%
from openai import OpenAI

# OpenAI istemcisi oluşturuluyor
client = OpenAI(api_key="18a96e3586fcdb0cf5466aa12f8060eae393f99cb054b15218714116ccb30b00a%3A2%3A%7Bi%3A0%3Bs%3A13%3A%22cookieControl%22%3Bi%3A1%3Bs%3A84%3A%22dc6ceaf283b2ebd4088d6e12bb331211b341a97a260436cc42a4fd8de287838bczo4OiJhcHByb3ZlZCI7%22%3B%7D")  # Buraya kendi API anahtarını eklemeyi unutma

def chat_with_gpt(prompt, history_list):
    # Yeni mesaj geçmişine son kullanıcı mesajını ekle
    history_list.append({"role": "user", "content": prompt})

    # Chat completion isteği gönder
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=history_list
    )

    # Chatbot yanıtını al
    reply = response.choices[0].message.content.strip()

    # Bot yanıtını da geçmişe ekle
    history_list.append({"role": "assistant", "content": reply})

    return reply

if __name__ == "__main__":
    history_list = []

    while True:
        user_input = input("Kullanıcı: ")

        if user_input.lower() in ["exit", "q"]:
            print("Konuşma tamamlandı.")
            break

        response = chat_with_gpt(user_input, history_list)
        print(f"Chatbot: {response}")
# Out:
# Kullanıcı:  selam
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[1], line 34
#      31     print("Konuşma tamamlandı.")
#      32     break
# ---> 34 response = chat_with_gpt(user_input, history_list)
#      35 print(f"Chatbot: {response}")
#
# Cell In[1], line 11, in chat_with_gpt(prompt, history_list)
#       8 history_list.append({"role": "user", "content": prompt})
#      10 # Chat completion isteği gönder
# ---> 11 response = client.chat.completions.create(
#      12     model="gpt-3.5-turbo",
#      13     messages=history_list
#      14 )
#      16 # Chatbot yanıtını al
#      17 reply = response.choices[0].message.content.strip()
#
# File D:\anaconda\lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
# ...
