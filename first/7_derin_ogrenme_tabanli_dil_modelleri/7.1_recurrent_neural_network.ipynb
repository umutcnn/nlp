# %%
"""
solve classification problem (sentiment analysis in nlp) with rnn(deep learnin based language model)

duygu analizi -> bir cümlenin etiketlenmesi (possitive ve negative)

restororant yorumları değerlendirme
"""
# Out:
# '\nsolve classification problem (sentiment analysis in nlp) with rnn(deep learnin based language model)\n\nduygu analizi -> bir cümlenin etiketlenmesi (possitive ve negative)\n\nrestororant yorumları değerlendirme\n'

# %%
# import libraries
import numpy as np 
import pandas as pd

#metin temsili
from gensim.models import Word2Vec

# 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import SimpleRNN,Dense,Embedding
from tensorflow.keras.preprocessing.text import Tokenizer



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# create database
data = {
    "text": [
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Mekânın ambiyansı harikaydı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Mekânın ambiyansı harikaydı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler zamanında ve sıcak geldi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Mekânın ambiyansı harikaydı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Mekânın ambiyansı harikaydı.",
        "Mekânın ambiyansı harikaydı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Yemekler zamanında ve sıcak geldi.",
        "Atmosfer çok hoştu, keyifli bir akşamdı.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler zamanında ve sıcak geldi.",
        "Servis çok iyiydi, garsonlar güler yüzlüydü.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Yemekler zamanında ve sıcak geldi.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Her şey tazeydi, çok memnun kaldık.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Çalışanlar çok nazik ve ilgiliydi.",
        "Yemekler harikaydı, ellerinize sağlık.",
        "Tatlılar çok lezzetliydi, tekrar gelmek isterim.",
        "Fiyatlar uygun ve porsiyonlar doyurucuydu.",
        "Kahve mükemmeldi, yanında gelen kurabiye de çok iyiydi.",
        "Mekânın ambiyansı harikaydı.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler pişmemişti, çiğdi.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler pişmemişti, çiğdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Yemekler pişmemişti, çiğdi.",
        "Tatlılar bayattı, yiyemedik.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Yemekler pişmemişti, çiğdi.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Siparişim yanlış geldi, değiştirmek zorunda kaldım.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Tatlılar bayattı, yiyemedik.",
        "Yemekler pişmemişti, çiğdi.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Masa kirliydi ve temizlik yetersizdi.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Tatlılar bayattı, yiyemedik.",
        "Kötü bir deneyimdi, tekrar gelmem.",
        "Fiyatlar çok yüksekti ve porsiyonlar küçüktü.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Tatlılar bayattı, yiyemedik.",
        "Garsonlar ilgisizdi ve siparişleri karıştırdılar.",
        "Servis çok yavaştı, uzun süre bekledik.",
        "Ortam çok gürültülüydü, rahatsız olduk.",
        "Mekân rahatsız ediciydi, hiç beğenmedim.",
        "Kahve sıcacıktı, çok memnun kaldım.",
        "Mekân güzeldi, çok memnun kaldım.",
        "Mekân kirliydi, hiç beğenmedim.",
        "Çalışanlar harikaydı, çok memnun kaldım.",
        "Ortam bayattı, hiç beğenmedim.",
        "Garsonlar çok kötüydü, hiç beğenmedim.",
        "Sipariş kirliydi, hiç beğenmedim.",
        "Yemekler güzeldi, çok memnun kaldım.",
        "Atmosfer çok hoştu, çok memnun kaldım.",
        "Mekân pişmemişti, hiç beğenmedim.",
        "Sipariş berbattı, hiç beğenmedim.",
        "Atmosfer sıcacıktı, çok memnun kaldım.",
        "Mekân yanlıştı, hiç beğenmedim.",
        "Masa üzücüydü, hiç beğenmedim.",
        "Yemekler yüksekti, hiç beğenmedim.",
        "Ortam çok kötüydü, hiç beğenmedim.",
        "Tatlılar sıcacıktı, çok memnun kaldım.",
        "Servis tazeydi, çok memnun kaldım.",
        "Mekân yavaştı, hiç beğenmedim.",
        "Yemekler berbattı, hiç beğenmedim.",
        "Garsonlar yavaştı, hiç beğenmedim.",
        "Yemekler kirliydi, hiç beğenmedim.",
        "Fiyatlar lezzetliydi, çok memnun kaldım.",
        "Fiyatlar yüksekti, hiç beğenmedim.",
        "Atmosfer doyurucuydu, çok memnun kaldım.",
        "Mekân bayattı, hiç beğenmedim.",
        "Mekân doyurucuydu, çok memnun kaldım.",
        "Atmosfer harikaydı, çok memnun kaldım.",
        "Tatlılar rahatsız ediciydi, hiç beğenmedim.",
        "Mekân çok hoştu, çok memnun kaldım.",
        "Her şey keyifliydi, çok memnun kaldım.",
        "Atmosfer mükemmeldi, çok memnun kaldım.",
        "Sipariş soğuktu, hiç beğenmedim.",
        "Çalışanlar çok hoştu, çok memnun kaldım.",
        "Yemekler üzücüydü, hiç beğenmedim.",
        "Masa rahatsız ediciydi, hiç beğenmedim.",
        "Sipariş pişmemişti, hiç beğenmedim.",
        "Ortam yüksekti, hiç beğenmedim.",
        "Servis rahatsız ediciydi, hiç beğenmedim.",
        "Garsonlar üzücüydü, hiç beğenmedim.",
        "Yemekler keyifliydi, çok memnun kaldım.",
        "Masa yanlıştı, hiç beğenmedim.",
        "Fiyatlar çok kötüydü, hiç beğenmedim.",
        "Fiyatlar soğuktu, hiç beğenmedim.",
        "Her şey lezzetliydi, çok memnun kaldım.",
        "Tatlılar yavaştı, hiç beğenmedim.",
        "Ortam yanlıştı, hiç beğenmedim.",
        "Kahve mükemmeldi, çok memnun kaldım.",
        "Servis doyurucuydu, çok memnun kaldım.",
        "Fiyatlar keyifliydi, çok memnun kaldım.",
        "Tatlılar yanlıştı, hiç beğenmedim.",
        "Çalışanlar güzeldi, çok memnun kaldım.",
        "Fiyatlar sıcacıktı, çok memnun kaldım.",
        "Tatlılar harikaydı, çok memnun kaldım.",
        "Fiyatlar kirliydi, hiç beğenmedim.",
        "Tatlılar mükemmeldi, çok memnun kaldım.",
        "Tatlılar bayattı, hiç beğenmedim.",
        "Garsonlar rahatsız ediciydi, hiç beğenmedim.",
        "Fiyatlar çok iyiydi, çok memnun kaldım.",
        "Garsonlar yanlıştı, hiç beğenmedim.",
        "Ortam rahatsız ediciydi, hiç beğenmedim.",
        "Mekân mükemmeldi, çok memnun kaldım.",
        "Tatlılar tazeydi, çok memnun kaldım.",
        "Mekân lezzetliydi, çok memnun kaldım.",
        "Servis bayattı, hiç beğenmedim.",
        "Yemekler pişmemişti, hiç beğenmedim.",
        "Servis çok hoştu, çok memnun kaldım.",
        "Masa çok kötüydü, hiç beğenmedim.",
        "Servis yüksekti, hiç beğenmedim.",
        "Garsonlar kirliydi, hiç beğenmedim.",
        "Tatlılar keyifliydi, çok memnun kaldım.",
        "Sipariş yüksekti, hiç beğenmedim.",
        "Fiyatlar harikaydı, çok memnun kaldım.",
        "Tatlılar doyurucuydu, çok memnun kaldım.",
        "Yemekler çok kötüydü, hiç beğenmedim.",
        "Mekân tazeydi, çok memnun kaldım.",
        "Garsonlar pişmemişti, hiç beğenmedim.",
        "Tatlılar nazikti, çok memnun kaldım.",
        "Kahve tazeydi, çok memnun kaldım.",
        "Servis soğuktu, hiç beğenmedim.",
        "Ortam yavaştı, hiç beğenmedim.",
        "Yemekler çok hoştu, çok memnun kaldım.",
        "Tatlılar çok iyiydi, çok memnun kaldım.",
        "Ortam kirliydi, hiç beğenmedim.",
        "Servis kirliydi, hiç beğenmedim.",
        "Atmosfer çok iyiydi, çok memnun kaldım.",
        "Mekân keyifliydi, çok memnun kaldım.",
        "Masa berbattı, hiç beğenmedim.",
        "Yemekler tazeydi, çok memnun kaldım.",
        "Her şey çok iyiydi, çok memnun kaldım.",
        "Sipariş bayattı, hiç beğenmedim.",
        "Mekân çok iyiydi, çok memnun kaldım.",
        "Tatlılar berbattı, hiç beğenmedim.",
        "Çalışanlar sıcacıktı, çok memnun kaldım.",
        "Ortam pişmemişti, hiç beğenmedim.",
        "Fiyatlar mükemmeldi, çok memnun kaldım.",
        "Tatlılar çok hoştu, çok memnun kaldım.",
        "Her şey tazeydi, çok memnun kaldım.",
        "Yemekler yanlıştı, hiç beğenmedim.",
        "Fiyatlar yavaştı, hiç beğenmedim.",
        "Sipariş rahatsız ediciydi, hiç beğenmedim.",
        "Tatlılar güzeldi, çok memnun kaldım.",
        "Fiyatlar berbattı, hiç beğenmedim.",
        "Tatlılar yüksekti, hiç beğenmedim.",
        "Masa yavaştı, hiç beğenmedim.",
        "Her şey çok hoştu, çok memnun kaldım.",
        "Yemekler harikaydı, çok memnun kaldım.",
        "Fiyatlar yanlıştı, hiç beğenmedim.",
        "Fiyatlar güzeldi, çok memnun kaldım.",
        "Çalışanlar lezzetliydi, çok memnun kaldım.",
        "Fiyatlar tazeydi, çok memnun kaldım.",
        "Servis yavaştı, hiç beğenmedim.",
        "Servis keyifliydi, çok memnun kaldım.",
        "Garsonlar bayattı, hiç beğenmedim.",
        "Mekân çok kötüydü, hiç beğenmedim.",
        "Çalışanlar doyurucuydu, çok memnun kaldım.",
        "Servis harikaydı, çok memnun kaldım.",
        "Kahve nazikti, çok memnun kaldım.",
        "Fiyatlar rahatsız ediciydi, hiç beğenmedim.",
        "Yemekler bayattı, hiç beğenmedim.",
        "Masa pişmemişti, hiç beğenmedim.",
        "Yemekler yavaştı, hiç beğenmedim.",
        "Atmosfer keyifliydi, çok memnun kaldım.",
        "Atmosfer güzeldi, çok memnun kaldım.",
        "Tatlılar lezzetliydi, çok memnun kaldım.",
        "Mekân soğuktu, hiç beğenmedim.",
        "Servis güzeldi, çok memnun kaldım.",
        "Garsonlar yüksekti, hiç beğenmedim.",
        "Her şey mükemmeldi, çok memnun kaldım.",
        "Her şey harikaydı, çok memnun kaldım.",
        "Masa yüksekti, hiç beğenmedim.",
        "Servis lezzetliydi, çok memnun kaldım.",
        "Fiyatlar çok hoştu, çok memnun kaldım.",
        "Ortam berbattı, hiç beğenmedim.",
        "Masa kirliydi, hiç beğenmedim.",
        "Çalışanlar keyifliydi, çok memnun kaldım.",
        "Servis çok iyiydi, çok memnun kaldım.",
        "Atmosfer tazeydi, çok memnun kaldım.",
        "Yemekler doyurucuydu, çok memnun kaldım.",
        "Mekân üzücüydü, hiç beğenmedim.",
        "Çalışanlar mükemmeldi, çok memnun kaldım.",
        "Kahve güzeldi, çok memnun kaldım.",
        "Sipariş yavaştı, hiç beğenmedim.",
        "Çalışanlar tazeydi, çok memnun kaldım.",
        "Yemekler nazikti, çok memnun kaldım.",
        "Fiyatlar pişmemişti, hiç beğenmedim.",
        "Servis üzücüydü, hiç beğenmedim.",
        "Servis pişmemişti, hiç beğenmedim.",
        "Fiyatlar üzücüydü, hiç beğenmedim.",
        "Her şey sıcacıktı, çok memnun kaldım.",
        "Kahve doyurucuydu, çok memnun kaldım.",
        "Tatlılar çok kötüydü, hiç beğenmedim.",
        "Fiyatlar bayattı, hiç beğenmedim.",
        "Servis nazikti, çok memnun kaldım.",
        "Tatlılar pişmemişti, hiç beğenmedim.",
        "Kahve keyifliydi, çok memnun kaldım.",
        "Yemekler sıcacıktı, çok memnun kaldım.",
        "Fiyatlar nazikti, çok memnun kaldım.",
        "Ortam soğuktu, hiç beğenmedim.",
        "Çalışanlar nazikti, çok memnun kaldım.",
        "Tatlılar soğuktu, hiç beğenmedim.",
        "Atmosfer lezzetliydi, çok memnun kaldım.",
        "Garsonlar berbattı, hiç beğenmedim.",
        "Yemekler rahatsız ediciydi, hiç beğenmedim.",
        "Kahve harikaydı, çok memnun kaldım.",
        "Her şey güzeldi, çok memnun kaldım.",
        "Masa soğuktu, hiç beğenmedim.",
        "Kahve çok iyiydi, çok memnun kaldım.",
        "Atmosfer nazikti, çok memnun kaldım.",
        "Mekân harikaydı, çok memnun kaldım.",
        "Servis sıcacıktı, çok memnun kaldım.",
        "Yemekler çok iyiydi, çok memnun kaldım.",
        "Servis çok kötüydü, hiç beğenmedim.",
        "Fiyatlar doyurucuydu, çok memnun kaldım.",
        "Yemekler lezzetliydi, çok memnun kaldım.",
        "Mekân berbattı, hiç beğenmedim.",
        "Sipariş çok kötüydü, hiç beğenmedim.",
        "Mekân yüksekti, hiç beğenmedim.",
        "Servis berbattı, hiç beğenmedim.",
        "Sipariş yanlıştı, hiç beğenmedim.",
        "Her şey doyurucuydu, çok memnun kaldım.",
        "Kahve çok hoştu, çok memnun kaldım.",
        "Mekân nazikti, çok memnun kaldım.",
        "Servis yanlıştı, hiç beğenmedim.",
        "Çalışanlar çok iyiydi, çok memnun kaldım.",
        "Masa bayattı, hiç beğenmedim.",
        "Garsonlar soğuktu, hiç beğenmedim.",
        "Kahve lezzetliydi, çok memnun kaldım.",
        "Tatlılar kirliydi, hiç beğenmedim.",
        "Tatlılar üzücüydü, hiç beğenmedim.",
        "Servis mükemmeldi, çok memnun kaldım.",
        "Yemekler mükemmeldi, çok memnun kaldım.",
        "Her şey nazikti, çok memnun kaldım.",
        "Mekân sıcacıktı, çok memnun kaldım.",
        "Yemekler soğuktu, hiç beğenmedim.",
        "Ortam üzücüydü, hiç beğenmedim.",
        "Sipariş üzücüydü, hiç beğenmedim.",
        "korkunçtu",
    "harika",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok kötü",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "rezalet",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "rezalet",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "efsane",
    "memnun kaldım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "berbat",
    "mükemmel",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok kötü",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok kötü",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç beğenmedim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "memnun kaldım",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "harika",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "efsane",
    "çok kötü",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "süper",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç beğenmedim",
    "memnun kaldım",
    "süper",
    "çok kötü",
    "mükemmel",
    "çok sevdim",
    "çok sevdim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "rezalet",
    "çok kötü",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok kötü",
    "korkunçtu",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "berbat",
    "hayal kırıklığı",
    "süper",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "harika",
    "efsane",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok iyiydi",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "mükemmel",
    "süper",
    "beğendim",
    "harika",
    "hiç beğenmedim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç memnun kalmadım",
    "çok iyiydi",
    "hiç memnun kalmadım",
    "efsane",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok sevdim",
    "çok kötü",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "süper",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "rezalet",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok sevdim",
    "çok iyiydi",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "harika",
    "hiç memnun kalmadım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "pişman oldum",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "korkunçtu",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç beğenmedim",
    "mükemmel",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "süper",
    "hiç memnun kalmadım",
    "berbat",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "harika",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "efsane",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "mükemmel",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "efsane",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "korkunçtu",
    "pişman oldum",
    "efsane",
    "harika",
    "beğendim",
    "memnun kaldım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "pişman oldum",
    "çok sevdim",
    "çok kötü",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "rezalet",
    "memnun kaldım",
    "berbat",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "korkunçtu",
    "beğendim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "efsane",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "efsane",
    "efsane",
    "hiç beğenmedim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "memnun kaldım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "harika",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hayal kırıklığı",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok sevdim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "mükemmel",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "mükemmel",
    "süper",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok iyiydi",
    "berbat",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç beğenmedim",
    "çok kötü",
    "hiç beğenmedim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "korkunçtu",
    "hiç memnun kalmadım",
    "hiç beğenmedim",
    "beğendim",
    "berbat",
    "süper",
    "çok kötü",
    "berbat",
    "pişman oldum",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "harika",
    "berbat",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok kötü",
    "hiç beğenmedim",
    "çok kötü",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok sevdim",
    "beğendim",
    "rezalet",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "berbat",
    "efsane",
    "çok kötü",
    "beğendim",
    "harika",
    "memnun kaldım",
    "rezalet",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "çok iyiydi",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "harika",
    "hayal kırıklığı",
    "memnun kaldım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "korkunçtu",
    "süper",
    "mükemmel",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "mükemmel",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "berbat",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "mükemmel",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "çok sevdim",
    "pişman oldum",
    "süper",
    "süper",
    "hiç beğenmedim",
    "çok iyiydi",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok sevdim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "harika",
    "memnun kaldım",
    "pişman oldum",
    "pişman oldum",
    "korkunçtu",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "süper",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "mükemmel",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "harika",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "memnun kaldım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok sevdim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "korkunçtu",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "memnun kaldım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "mükemmel",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "memnun kaldım",
    "korkunçtu",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok kötü",
    "çok iyiydi",
    "süper",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "süper",
    "çok kötü",
    "çok iyiydi",
    "beğendim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "süper",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok iyiydi",
    "berbat",
    "Servis çok yavaştı, uzun süre bekledik.",
    "pişman oldum",
    "rezalet",
    "çok sevdim",
    "çok sevdim",
    "mükemmel",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "korkunçtu",
    "hiç memnun kalmadım",
    "süper",
    "korkunçtu",
    "harika",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "beğendim",
    "çok iyiydi",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hayal kırıklığı",
    "berbat",
    "rezalet",
    "berbat",
    "korkunçtu",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç memnun kalmadım",
    "çok kötü",
    "süper",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok iyiydi",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "beğendim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok iyiydi",
    "çok kötü",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "memnun kaldım",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hayal kırıklığı",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hayal kırıklığı",
    "memnun kaldım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "pişman oldum",
    "hiç memnun kalmadım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok iyiydi",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "harika",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok kötü",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok kötü",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "korkunçtu",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "harika",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok iyiydi",
    "süper",
    "çok iyiydi",
    "rezalet",
    "hiç memnun kalmadım",
    "çok sevdim",
    "hayal kırıklığı",
    "çok iyiydi",
    "hiç beğenmedim",
    "korkunçtu",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "efsane",
    "çok iyiydi",
    "çok sevdim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "efsane",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok iyiydi",
    "çok kötü",
    "beğendim",
    "çok sevdim",
    "çok kötü",
    "pişman oldum",
    "hiç memnun kalmadım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç beğenmedim",
    "çok kötü",
    "çok kötü",
    "çok iyiydi",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok sevdim",
    "pişman oldum",
    "memnun kaldım",
    "efsane",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç memnun kalmadım",
    "berbat",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "berbat",
    "rezalet",
    "efsane",
    "beğendim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "berbat",
    "hiç memnun kalmadım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "beğendim",
    "harika",
    "harika",
    "korkunçtu",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç beğenmedim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "süper",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "rezalet",
    "süper",
    "harika",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "beğendim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "harika",
    "çok iyiydi",
    "rezalet",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "korkunçtu",
    "çok iyiydi",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "pişman oldum",
    "pişman oldum",
    "çok sevdim",
    "harika",
    "harika",
    "pişman oldum",
    "pişman oldum",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "harika",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok kötü",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "efsane",
    "hiç beğenmedim",
    "süper",
    "korkunçtu",
    "çok iyiydi",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "memnun kaldım",
    "hiç beğenmedim",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "berbat",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "memnun kaldım",
    "çok kötü",
    "çok sevdim",
    "mükemmel",
    "hayal kırıklığı",
    "memnun kaldım",
    "mükemmel",
    "süper",
    "pişman oldum",
    "memnun kaldım",
    "hayal kırıklığı",
    "efsane",
    "beğendim",
    "berbat",
    "berbat",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç memnun kalmadım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "memnun kaldım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "berbat",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok kötü",
    "berbat",
    "çok sevdim",
    "beğendim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "beğendim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç beğenmedim",
    "beğendim",
    "efsane",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "rezalet",
    "çok kötü",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç beğenmedim",
    "korkunçtu",
    "rezalet",
    "efsane",
    "memnun kaldım",
    "çok iyiydi",
    "berbat",
    "memnun kaldım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok sevdim",
    "korkunçtu",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "efsane",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hayal kırıklığı",
    "memnun kaldım",
    "çok iyiydi",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "süper",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "mükemmel",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok sevdim",
    "çok kötü",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç memnun kalmadım",
    "süper",
    "Servis çok yavaştı, uzun süre bekledik.",
    "rezalet",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "beğendim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "efsane",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok iyiydi",
    "pişman oldum",
    "efsane",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "efsane",
    "çok iyiydi",
    "hayal kırıklığı",
    "berbat",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "pişman oldum",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "beğendim",
    "korkunçtu",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "süper",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hayal kırıklığı",
    "hiç beğenmedim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç memnun kalmadım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "mükemmel",
    "rezalet",
    "berbat",
    "pişman oldum",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "pişman oldum",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "korkunçtu",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "memnun kaldım",
    "rezalet",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok kötü",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "berbat",
    "hayal kırıklığı",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok iyiydi",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok kötü",
    "pişman oldum",
    "hayal kırıklığı",
    "rezalet",
    "beğendim",
    "pişman oldum",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "mükemmel",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç beğenmedim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "rezalet",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "harika",
    "efsane",
    "süper",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "çok kötü",
    "rezalet",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç beğenmedim",
    "pişman oldum",
    "süper",
    "çok kötü",
    "korkunçtu",
    "çok iyiydi",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok iyiydi",
    "çok kötü",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "memnun kaldım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hayal kırıklığı",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "korkunçtu",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok iyiydi",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "pişman oldum",
    "çok sevdim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "rezalet",
    "korkunçtu",
    "mükemmel",
    "efsane",
    "pişman oldum",
    "korkunçtu",
    "pişman oldum",
    "hayal kırıklığı",
    "çok iyiydi",
    "korkunçtu",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok iyiydi",
    "berbat",
    "beğendim",
    "rezalet",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "pişman oldum",
    "süper",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç beğenmedim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "harika",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "korkunçtu",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "mükemmel",
    "çok kötü",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "rezalet",
    "rezalet",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok kötü",
    "korkunçtu",
    "harika",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hayal kırıklığı",
    "berbat",
    "hiç beğenmedim",
    "çok kötü",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç beğenmedim",
    "çok sevdim",
    "berbat",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "çok sevdim",
    "rezalet",
    "çok kötü",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "berbat",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok sevdim",
    "harika",
    "çok sevdim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "efsane",
    "çok iyiydi",
    "efsane",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok kötü",
    "harika",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "efsane",
    "çok iyiydi",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "berbat",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "berbat",
    "berbat",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "pişman oldum",
    "berbat",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "harika",
    "çok iyiydi",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok iyiydi",
    "korkunçtu",
    "berbat",
    "süper",
    "mükemmel",
    "rezalet",
    "rezalet",
    "süper",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "berbat",
    "beğendim",
    "memnun kaldım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç memnun kalmadım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "efsane",
    "rezalet",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "hayal kırıklığı",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "süper",
    "çok iyiydi",
    "hiç memnun kalmadım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok kötü",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hayal kırıklığı",
    "berbat",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok kötü",
    "çok sevdim",
    "berbat",
    "korkunçtu",
    "korkunçtu",
    "çok iyiydi",
    "memnun kaldım",
    "rezalet",
    "çok sevdim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "beğendim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "berbat",
    "harika",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "beğendim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok kötü",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "berbat",
    "memnun kaldım",
    "çok iyiydi",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "memnun kaldım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "mükemmel",
    "memnun kaldım",
    "pişman oldum",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "efsane",
    "hayal kırıklığı",
    "hiç memnun kalmadım",
    "beğendim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "mükemmel",
    "beğendim",
    "harika",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "rezalet",
    "çok sevdim",
    "hayal kırıklığı",
    "harika",
    "beğendim",
    "rezalet",
    "berbat",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "çok kötü",
    "hayal kırıklığı",
    "efsane",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "efsane",
    "berbat",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "beğendim",
    "rezalet",
    "harika",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "harika",
    "Servis çok yavaştı, uzun süre bekledik.",
    "mükemmel",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "süper",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç beğenmedim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "berbat",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "mükemmel",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "süper",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok sevdim",
    "hiç memnun kalmadım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "mükemmel",
    "mükemmel",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "mükemmel",
    "berbat",
    "efsane",
    "hayal kırıklığı",
    "beğendim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "memnun kaldım",
    "memnun kaldım",
    "çok kötü",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "korkunçtu",
    "çok iyiydi",
    "çok iyiydi",
    "süper",
    "rezalet",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "beğendim",
    "harika",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "harika",
    "rezalet",
    "hiç beğenmedim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "pişman oldum",
    "çok iyiydi",
    "çok kötü",
    "süper",
    "mükemmel",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "berbat",
    "harika",
    "hiç beğenmedim",
    "efsane",
    "çok iyiydi",
    "berbat",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "harika",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok sevdim",
    "çok iyiydi",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç beğenmedim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç memnun kalmadım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "süper",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "pişman oldum",
    "mükemmel",
    "rezalet",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç beğenmedim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok iyiydi",
    "harika",
    "Servis çok yavaştı, uzun süre bekledik.",
    "pişman oldum",
    "berbat",
    "çok kötü",
    "çok iyiydi",
    "beğendim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "süper",
    "süper",
    "rezalet",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok sevdim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok kötü",
    "mükemmel",
    "çok sevdim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "harika",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok kötü",
    "hiç beğenmedim",
    "çok sevdim",
    "efsane",
    "çok iyiydi",
    "çok sevdim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok iyiydi",
    "korkunçtu",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "harika",
    "memnun kaldım",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "berbat",
    "çok iyiydi",
    "rezalet",
    "memnun kaldım",
    "berbat",
    "memnun kaldım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç beğenmedim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "rezalet",
    "çok kötü",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok sevdim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "harika",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok sevdim",
    "çok iyiydi",
    "beğendim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok sevdim",
    "çok iyiydi",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "süper",
    "çok sevdim",
    "rezalet",
    "hiç beğenmedim",
    "hiç memnun kalmadım",
    "harika",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "hiç beğenmedim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç beğenmedim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hiç beğenmedim",
    "beğendim",
    "efsane",
    "berbat",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "pişman oldum",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok sevdim",
    "memnun kaldım",
    "hiç beğenmedim",
    "hiç beğenmedim",
    "berbat",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "beğendim",
    "harika",
    "hiç memnun kalmadım",
    "rezalet",
    "çok iyiydi",
    "hayal kırıklığı",
    "berbat",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "harika",
    "rezalet",
    "hiç memnun kalmadım",
    "beğendim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "memnun kaldım",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "efsane",
    "beğendim",
    "çok kötü",
    "korkunçtu",
    "Servis çok yavaştı, uzun süre bekledik.",
    "berbat",
    "hiç memnun kalmadım",
    "mükemmel",
    "pişman oldum",
    "mükemmel",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "harika",
    "çok iyiydi",
    "hiç memnun kalmadım",
    "çok iyiydi",
    "mükemmel",
    "pişman oldum",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "berbat",
    "harika",
    "hiç memnun kalmadım",
    "rezalet",
    "çok iyiydi",
    "memnun kaldım",
    "hiç beğenmedim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "harika",
    "çok sevdim",
    "hiç beğenmedim",
    "hiç memnun kalmadım",
    "rezalet",
    "korkunçtu",
    "süper",
    "memnun kaldım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "mükemmel",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "mükemmel",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "memnun kaldım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç beğenmedim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "memnun kaldım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "memnun kaldım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "berbat",
    "çok kötü",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hayal kırıklığı",
    "beğendim",
    "çok sevdim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "mükemmel",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "berbat",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "efsane",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "memnun kaldım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok iyiydi",
    "beğendim",
    "memnun kaldım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç memnun kalmadım",
    "pişman oldum",
    "hiç beğenmedim",
    "çok iyiydi",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "pişman oldum",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "beğendim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok kötü",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok sevdim",
    "hayal kırıklığı",
    "süper",
    "harika",
    "süper",
    "hiç beğenmedim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "rezalet",
    "berbat",
    "Servis çok yavaştı, uzun süre bekledik.",
    "harika",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok sevdim",
    "efsane",
    "harika",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "pişman oldum",
    "beğendim",
    "memnun kaldım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "mükemmel",
    "süper",
    "harika",
    "pişman oldum",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "efsane",
    "rezalet",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "süper",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "mükemmel",
    "Servis çok yavaştı, uzun süre bekledik.",
    "berbat",
    "Servis çok yavaştı, uzun süre bekledik.",
    "korkunçtu",
    "hiç memnun kalmadım",
    "harika",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "çok kötü",
    "hayal kırıklığı",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "süper",
    "hiç beğenmedim",
    "hiç beğenmedim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok kötü",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "mükemmel",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "harika",
    "hiç beğenmedim",
    "hiç memnun kalmadım",
    "çok kötü",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "harika",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "efsane",
    "efsane",
    "rezalet",
    "hayal kırıklığı",
    "çok sevdim",
    "efsane",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "süper",
    "rezalet",
    "beğendim",
    "berbat",
    "çok iyiydi",
    "mükemmel",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "pişman oldum",
    "berbat",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "memnun kaldım",
    "efsane",
    "mükemmel",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok sevdim",
    "korkunçtu",
    "hiç beğenmedim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "çok iyiydi",
    "memnun kaldım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "süper",
    "memnun kaldım",
    "harika",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "korkunçtu",
    "hiç beğenmedim",
    "mükemmel",
    "memnun kaldım",
    "hiç memnun kalmadım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç memnun kalmadım",
    "efsane",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "memnun kaldım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "hayal kırıklığı",
    "çok sevdim",
    "harika",
    "memnun kaldım",
    "memnun kaldım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok kötü",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "memnun kaldım",
    "hiç memnun kalmadım",
    "pişman oldum",
    "beğendim",
    "hayal kırıklığı",
    "süper",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "efsane",
    "memnun kaldım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "beğendim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok iyiydi",
    "mükemmel",
    "efsane",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok kötü",
    "hiç memnun kalmadım",
    "memnun kaldım",
    "hayal kırıklığı",
    "çok sevdim",
    "berbat",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "berbat",
    "rezalet",
    "beğendim",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "berbat",
    "pişman oldum",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "beğendim",
    "hiç beğenmedim",
    "beğendim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "beğendim",
    "rezalet",
    "korkunçtu",
    "berbat",
    "hayal kırıklığı",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "mükemmel",
    "hayal kırıklığı",
    "rezalet",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok sevdim",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "harika",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hayal kırıklığı",
    "çok sevdim",
    "efsane",
    "rezalet",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hayal kırıklığı",
    "berbat",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "berbat",
    "hiç beğenmedim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "berbat",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "berbat",
    "rezalet",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "beğendim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "süper",
    "memnun kaldım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "beğendim",
    "harika",
    "memnun kaldım",
    "hiç beğenmedim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "korkunçtu",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "süper",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok kötü",
    "süper",
    "harika",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç beğenmedim",
    "efsane",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "pişman oldum",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç beğenmedim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "berbat",
    "çok kötü",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok kötü",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç memnun kalmadım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hayal kırıklığı",
    "berbat",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok kötü",
    "harika",
    "korkunçtu",
    "hayal kırıklığı",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "süper",
    "çok sevdim",
    "berbat",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç beğenmedim",
    "harika",
    "mükemmel",
    "çok kötü",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "çok sevdim",
    "çok sevdim",
    "rezalet",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "mükemmel",
    "çok kötü",
    "memnun kaldım",
    "pişman oldum",
    "berbat",
    "pişman oldum",
    "hiç beğenmedim",
    "süper",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "beğendim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "pişman oldum",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç memnun kalmadım",
    "pişman oldum",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç memnun kalmadım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "mükemmel",
    "beğendim",
    "süper",
    "Servis çok yavaştı, uzun süre bekledik.",
    "beğendim",
    "çok iyiydi",
    "rezalet",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "efsane",
    "çok iyiydi",
    "memnun kaldım",
    "çok sevdim",
    "mükemmel",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "berbat",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "çok iyiydi",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "mükemmel",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç beğenmedim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "pişman oldum",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok kötü",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "beğendim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "rezalet",
    "memnun kaldım",
    "berbat",
    "pişman oldum",
    "hayal kırıklığı",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç memnun kalmadım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "süper",
    "beğendim",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "memnun kaldım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "harika",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "mükemmel",
    "beğendim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "efsane",
    "süper",
    "hiç beğenmedim",
    "efsane",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "mükemmel",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "pişman oldum",
    "berbat",
    "rezalet",
    "rezalet",
    "çok sevdim",
    "pişman oldum",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok iyiydi",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok kötü",
    "çok sevdim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hayal kırıklığı",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "rezalet",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "pişman oldum",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "mükemmel",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "süper",
    "çok kötü",
    "memnun kaldım",
    "çok kötü",
    "harika",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "süper",
    "rezalet",
    "hiç memnun kalmadım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "harika",
    "harika",
    "harika",
    "hiç beğenmedim",
    "çok kötü",
    "beğendim",
    "berbat",
    "harika",
    "pişman oldum",
    "beğendim",
    "pişman oldum",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "memnun kaldım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç beğenmedim",
    "rezalet",
    "pişman oldum",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "hiç memnun kalmadım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "berbat",
    "hiç memnun kalmadım",
    "mükemmel",
    "çok iyiydi",
    "memnun kaldım",
    "efsane",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "memnun kaldım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "çok kötü",
    "mükemmel",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "harika",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç beğenmedim",
    "harika",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "süper",
    "çok sevdim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "süper",
    "çok kötü",
    "mükemmel",
    "memnun kaldım",
    "çok sevdim",
    "hiç beğenmedim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "harika",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç memnun kalmadım",
    "hiç memnun kalmadım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "rezalet",
    "mükemmel",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "süper",
    "mükemmel",
    "süper",
    "berbat",
    "berbat",
    "korkunçtu",
    "memnun kaldım",
    "hiç beğenmedim",
    "hiç beğenmedim",
    "rezalet",
    "hiç beğenmedim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "korkunçtu",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "korkunçtu",
    "berbat",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "beğendim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "pişman oldum",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok kötü",
    "hiç beğenmedim",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok iyiydi",
    "hiç beğenmedim",
    "efsane",
    "çok kötü",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "korkunçtu",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "mükemmel",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "berbat",
    "çok iyiydi",
    "mükemmel",
    "efsane",
    "mükemmel",
    "mükemmel",
    "beğendim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hayal kırıklığı",
    "rezalet",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç memnun kalmadım",
    "çok kötü",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok kötü",
    "memnun kaldım",
    "beğendim",
    "berbat",
    "hiç memnun kalmadım",
    "efsane",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "beğendim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç memnun kalmadım",
    "pişman oldum",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok sevdim",
    "hiç beğenmedim",
    "korkunçtu",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok kötü",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç memnun kalmadım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "süper",
    "Servis çok yavaştı, uzun süre bekledik.",
    "mükemmel",
    "berbat",
    "efsane",
    "hiç beğenmedim",
    "berbat",
    "Servis çok yavaştı, uzun süre bekledik.",
    "harika",
    "hayal kırıklığı",
    "beğendim",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç beğenmedim",
    "süper",
    "çok kötü",
    "memnun kaldım",
    "çok iyiydi",
    "memnun kaldım",
    "çok kötü",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hiç memnun kalmadım",
    "çok sevdim",
    "berbat",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "korkunçtu",
    "hiç beğenmedim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "korkunçtu",
    "mükemmel",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "memnun kaldım",
    "hiç memnun kalmadım",
    "berbat",
    "mükemmel",
    "hiç beğenmedim",
    "pişman oldum",
    "memnun kaldım",
    "memnun kaldım",
    "rezalet",
    "efsane",
    "çok iyiydi",
    "süper",
    "memnun kaldım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok iyiydi",
    "pişman oldum",
    "süper",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "berbat",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok sevdim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç beğenmedim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok kötü",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "harika",
    "çok sevdim",
    "efsane",
    "efsane",
    "efsane",
    "efsane",
    "harika",
    "korkunçtu",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hayal kırıklığı",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç beğenmedim",
    "çok iyiydi",
    "harika",
    "süper",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç beğenmedim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "memnun kaldım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "süper",
    "efsane",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hayal kırıklığı",
    "berbat",
    "çok iyiydi",
    "hiç beğenmedim",
    "memnun kaldım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç beğenmedim",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç beğenmedim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hayal kırıklığı",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "korkunçtu",
    "hiç memnun kalmadım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hayal kırıklığı",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "harika",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok kötü",
    "çok iyiydi",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "berbat",
    "beğendim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "mükemmel",
    "memnun kaldım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok kötü",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "rezalet",
    "hiç memnun kalmadım",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "mükemmel",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok iyiydi",
    "çok kötü",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "korkunçtu",
    "memnun kaldım",
    "efsane",
    "hayal kırıklığı",
    "korkunçtu",
    "süper",
    "çok sevdim",
    "efsane",
    "pişman oldum",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "rezalet",
    "çok sevdim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "efsane",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "beğendim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok iyiydi",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "memnun kaldım",
    "efsane",
    "çok iyiydi",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok kötü",
    "harika",
    "çok iyiydi",
    "pişman oldum",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "berbat",
    "çok sevdim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç memnun kalmadım",
    "korkunçtu",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "efsane",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "berbat",
    "hiç beğenmedim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç beğenmedim",
    "çok kötü",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç memnun kalmadım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "memnun kaldım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "süper",
    "süper",
    "mükemmel",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "efsane",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "mükemmel",
    "hiç beğenmedim",
    "süper",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "memnun kaldım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "harika",
    "çok kötü",
    "rezalet",
    "harika",
    "hiç beğenmedim",
    "hiç memnun kalmadım",
    "harika",
    "beğendim",
    "çok iyiydi",
    "efsane",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok iyiydi",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hayal kırıklığı",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "harika",
    "memnun kaldım",
    "korkunçtu",
    "Servis çok yavaştı, uzun süre bekledik.",
    "süper",
    "süper",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok iyiydi",
    "hayal kırıklığı",
    "hiç beğenmedim",
    "mükemmel",
    "hiç memnun kalmadım",
    "süper",
    "korkunçtu",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "pişman oldum",
    "harika",
    "memnun kaldım",
    "beğendim",
    "efsane",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "memnun kaldım",
    "pişman oldum",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "rezalet",
    "mükemmel",
    "pişman oldum",
    "süper",
    "harika",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "korkunçtu",
    "harika",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "harika",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hayal kırıklığı",
    "çok iyiydi",
    "beğendim",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "hiç beğenmedim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç memnun kalmadım",
    "hayal kırıklığı",
    "berbat",
    "pişman oldum",
    "hayal kırıklığı",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "çok sevdim",
    "beğendim",
    "beğendim",
    "çok kötü",
    "süper",
    "çok sevdim",
    "beğendim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok sevdim",
    "efsane",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "mükemmel",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "pişman oldum",
    "memnun kaldım",
    "hiç beğenmedim",
    "memnun kaldım",
    "hiç memnun kalmadım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "efsane",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "beğendim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "korkunçtu",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç memnun kalmadım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok kötü",
    "hiç memnun kalmadım",
    "çok iyiydi",
    "çok iyiydi",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "memnun kaldım",
    "efsane",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "korkunçtu",
    "hiç beğenmedim",
    "pişman oldum",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "süper",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "efsane",
    "hiç memnun kalmadım",
    "hiç memnun kalmadım",
    "rezalet",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç beğenmedim",
    "harika",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "mükemmel",
    "efsane",
    "çok iyiydi",
    "hayal kırıklığı",
    "memnun kaldım",
    "memnun kaldım",
    "korkunçtu",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "mükemmel",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "harika",
    "pişman oldum",
    "beğendim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "efsane",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "harika",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç beğenmedim",
    "korkunçtu",
    "memnun kaldım",
    "süper",
    "rezalet",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok kötü",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç beğenmedim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "mükemmel",
    "çok sevdim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç beğenmedim",
    "beğendim",
    "çok kötü",
    "korkunçtu",
    "mükemmel",
    "çok iyiydi",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "harika",
    "hiç memnun kalmadım",
    "hayal kırıklığı",
    "harika",
    "süper",
    "hiç beğenmedim",
    "mükemmel",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "memnun kaldım",
    "rezalet",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "memnun kaldım",
    "korkunçtu",
    "efsane",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "pişman oldum",
    "çok iyiydi",
    "hiç beğenmedim",
    "süper",
    "harika",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "rezalet",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "süper",
    "çok sevdim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok kötü",
    "hiç beğenmedim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "efsane",
    "beğendim",
    "beğendim",
    "çok kötü",
    "korkunçtu",
    "beğendim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "süper",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "efsane",
    "mükemmel",
    "memnun kaldım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok sevdim",
    "beğendim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "efsane",
    "çok sevdim",
    "çok iyiydi",
    "hiç beğenmedim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "beğendim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "süper",
    "pişman oldum",
    "memnun kaldım",
    "berbat",
    "berbat",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok kötü",
    "mükemmel",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "süper",
    "çok sevdim",
    "süper",
    "korkunçtu",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "memnun kaldım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok sevdim",
    "çok kötü",
    "beğendim",
    "memnun kaldım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "mükemmel",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "korkunçtu",
    "hayal kırıklığı",
    "pişman oldum",
    "hayal kırıklığı",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "süper",
    "efsane",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "beğendim",
    "çok sevdim",
    "hiç beğenmedim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hayal kırıklığı",
    "beğendim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç memnun kalmadım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "memnun kaldım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "hiç beğenmedim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "pişman oldum",
    "hiç beğenmedim",
    "korkunçtu",
    "efsane",
    "hayal kırıklığı",
    "hiç memnun kalmadım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "hiç memnun kalmadım",
    "hiç beğenmedim",
    "hayal kırıklığı",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "süper",
    "çok iyiydi",
    "berbat",
    "çok iyiydi",
    "mükemmel",
    "süper",
    "çok iyiydi",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "beğendim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "efsane",
    "çok kötü",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç memnun kalmadım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "hayal kırıklığı",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok sevdim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "mükemmel",
    "memnun kaldım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "memnun kaldım",
    "berbat",
    "çok sevdim",
    "memnun kaldım",
    "süper",
    "efsane",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok kötü",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "pişman oldum",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç beğenmedim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "beğendim",
    "memnun kaldım",
    "çok sevdim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç memnun kalmadım",
    "çok sevdim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "süper",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "berbat",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok sevdim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç memnun kalmadım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok iyiydi",
    "çok sevdim",
    "mükemmel",
    "mükemmel",
    "hiç memnun kalmadım",
    "korkunçtu",
    "rezalet",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "mükemmel",
    "hiç memnun kalmadım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "memnun kaldım",
    "mükemmel",
    "korkunçtu",
    "harika",
    "efsane",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "efsane",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hayal kırıklığı",
    "mükemmel",
    "hiç memnun kalmadım",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hayal kırıklığı",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "pişman oldum",
    "harika",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "süper",
    "memnun kaldım",
    "berbat",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "korkunçtu",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç memnun kalmadım",
    "çok iyiydi",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "harika",
    "mükemmel",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "efsane",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "memnun kaldım",
    "çok kötü",
    "mükemmel",
    "Servis çok yavaştı, uzun süre bekledik.",
    "harika",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "rezalet",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç memnun kalmadım",
    "pişman oldum",
    "memnun kaldım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "pişman oldum",
    "hiç memnun kalmadım",
    "mükemmel",
    "süper",
    "hayal kırıklığı",
    "rezalet",
    "hiç beğenmedim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç memnun kalmadım",
    "çok sevdim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç beğenmedim",
    "çok iyiydi",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hiç memnun kalmadım",
    "hiç memnun kalmadım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hayal kırıklığı",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "efsane",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç memnun kalmadım",
    "memnun kaldım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "süper",
    "pişman oldum",
    "mükemmel",
    "mükemmel",
    "mükemmel",
    "efsane",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "memnun kaldım",
    "harika",
    "çok iyiydi",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "hiç beğenmedim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hayal kırıklığı",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "korkunçtu",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hiç memnun kalmadım",
    "harika",
    "hiç memnun kalmadım",
    "çok sevdim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "memnun kaldım",
    "mükemmel",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok sevdim",
    "pişman oldum",
    "hayal kırıklığı",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "rezalet",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "korkunçtu",
    "çok sevdim",
    "hiç memnun kalmadım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "süper",
    "mükemmel",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok kötü",
    "rezalet",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hayal kırıklığı",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hayal kırıklığı",
    "efsane",
    "hayal kırıklığı",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hiç beğenmedim",
    "mükemmel",
    "süper",
    "memnun kaldım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "efsane",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hayal kırıklığı",
    "mükemmel",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok sevdim",
    "hiç beğenmedim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç beğenmedim",
    "pişman oldum",
    "hiç memnun kalmadım",
    "harika",
    "mükemmel",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok kötü",
    "mükemmel",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "harika",
    "korkunçtu",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç memnun kalmadım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "pişman oldum",
    "mükemmel",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok sevdim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "memnun kaldım",
    "beğendim",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "berbat",
    "berbat",
    "çok kötü",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok iyiydi",
    "çok sevdim",
    "mükemmel",
    "süper",
    "hiç memnun kalmadım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "pişman oldum",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok iyiydi",
    "mükemmel",
    "beğendim",
    "efsane",
    "süper",
    "pişman oldum",
    "çok kötü",
    "beğendim",
    "süper",
    "çok iyiydi",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "mükemmel",
    "çok sevdim",
    "mükemmel",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok kötü",
    "çok kötü",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "mükemmel",
    "efsane",
    "harika",
    "berbat",
    "korkunçtu",
    "hiç beğenmedim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "beğendim",
    "hiç memnun kalmadım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "rezalet",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok sevdim",
    "harika",
    "çok sevdim",
    "mükemmel",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok kötü",
    "hiç beğenmedim",
    "korkunçtu",
    "memnun kaldım",
    "süper",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "harika",
    "beğendim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "mükemmel",
    "korkunçtu",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok kötü",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok sevdim",
    "beğendim",
    "berbat",
    "pişman oldum",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok kötü",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok sevdim",
    "pişman oldum",
    "beğendim",
    "mükemmel",
    "memnun kaldım",
    "berbat",
    "harika",
    "efsane",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "beğendim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "mükemmel",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok kötü",
    "süper",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "pişman oldum",
    "pişman oldum",
    "memnun kaldım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok kötü",
    "çok kötü",
    "beğendim",
    "süper",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "beğendim",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "pişman oldum",
    "hayal kırıklığı",
    "süper",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "harika",
    "çok iyiydi",
    "harika",
    "efsane",
    "rezalet",
    "berbat",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok sevdim",
    "çok kötü",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "korkunçtu",
    "berbat",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç memnun kalmadım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "süper",
    "memnun kaldım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "korkunçtu",
    "berbat",
    "berbat",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "rezalet",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hayal kırıklığı",
    "pişman oldum",
    "mükemmel",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç memnun kalmadım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok kötü",
    "korkunçtu",
    "mükemmel",
    "çok iyiydi",
    "hayal kırıklığı",
    "harika",
    "memnun kaldım",
    "efsane",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "mükemmel",
    "süper",
    "süper",
    "hiç beğenmedim",
    "memnun kaldım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "süper",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "berbat",
    "çok sevdim",
    "hayal kırıklığı",
    "harika",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok sevdim",
    "hiç memnun kalmadım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "memnun kaldım",
    "çok iyiydi",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "efsane",
    "süper",
    "Servis çok yavaştı, uzun süre bekledik.",
    "mükemmel",
    "pişman oldum",
    "Servis çok yavaştı, uzun süre bekledik.",
    "harika",
    "korkunçtu",
    "mükemmel",
    "hiç beğenmedim",
    "hayal kırıklığı",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç memnun kalmadım",
    "memnun kaldım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "korkunçtu",
    "korkunçtu",
    "pişman oldum",
    "berbat",
    "mükemmel",
    "hayal kırıklığı",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok sevdim",
    "çok iyiydi",
    "hayal kırıklığı",
    "efsane",
    "süper",
    "beğendim",
    "çok kötü",
    "beğendim",
    "harika",
    "süper",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "pişman oldum",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok sevdim",
    "çok sevdim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "korkunçtu",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "berbat",
    "harika",
    "mükemmel",
    "hiç beğenmedim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "berbat",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "pişman oldum",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç memnun kalmadım",
    "hayal kırıklığı",
    "memnun kaldım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "berbat",
    "beğendim",
    "çok sevdim",
    "rezalet",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "rezalet",
    "hiç beğenmedim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç beğenmedim",
    "mükemmel",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "çok iyiydi",
    "hiç beğenmedim",
    "hiç beğenmedim",
    "süper",
    "memnun kaldım",
    "çok iyiydi",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç beğenmedim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "süper",
    "beğendim",
    "süper",
    "çok sevdim",
    "efsane",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok iyiydi",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "memnun kaldım",
    "mükemmel",
    "süper",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok iyiydi",
    "korkunçtu",
    "pişman oldum",
    "beğendim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "memnun kaldım",
    "hiç beğenmedim",
    "efsane",
    "çok sevdim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "berbat",
    "Servis çok yavaştı, uzun süre bekledik.",
    "süper",
    "memnun kaldım",
    "rezalet",
    "çok sevdim",
    "pişman oldum",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "mükemmel",
    "efsane",
    "süper",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok iyiydi",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "memnun kaldım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç memnun kalmadım",
    "mükemmel",
    "hiç memnun kalmadım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok sevdim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "harika",
    "hayal kırıklığı",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok iyiydi",
    "çok kötü",
    "beğendim",
    "rezalet",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "berbat",
    "memnun kaldım",
    "hiç beğenmedim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "efsane",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok kötü",
    "berbat",
    "süper",
    "berbat",
    "pişman oldum",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç beğenmedim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç beğenmedim",
    "süper",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hayal kırıklığı",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hiç memnun kalmadım",
    "hiç beğenmedim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok kötü",
    "pişman oldum",
    "memnun kaldım",
    "hayal kırıklığı",
    "berbat",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hayal kırıklığı",
    "pişman oldum",
    "hiç memnun kalmadım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "beğendim",
    "çok sevdim",
    "rezalet",
    "memnun kaldım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "korkunçtu",
    "pişman oldum",
    "rezalet",
    "rezalet",
    "hiç beğenmedim",
    "hiç memnun kalmadım",
    "rezalet",
    "harika",
    "çok sevdim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "berbat",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "pişman oldum",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "pişman oldum",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç memnun kalmadım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok kötü",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç memnun kalmadım",
    "beğendim",
    "pişman oldum",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "korkunçtu",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok sevdim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "mükemmel",
    "süper",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok sevdim",
    "memnun kaldım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "harika",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hiç memnun kalmadım",
    "berbat",
    "hiç beğenmedim",
    "memnun kaldım",
    "mükemmel",
    "çok kötü",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "efsane",
    "memnun kaldım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok sevdim",
    "hiç memnun kalmadım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "rezalet",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "efsane",
    "hayal kırıklığı",
    "rezalet",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "hiç beğenmedim",
    "hiç memnun kalmadım",
    "efsane",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "pişman oldum",
    "hiç beğenmedim",
    "berbat",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "beğendim",
    "harika",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "korkunçtu",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "berbat",
    "mükemmel",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "memnun kaldım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "korkunçtu",
    "süper",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "memnun kaldım",
    "hayal kırıklığı",
    "harika",
    "süper",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok sevdim",
    "çok iyiydi",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç memnun kalmadım",
    "rezalet",
    "çok iyiydi",
    "pişman oldum",
    "Servis çok yavaştı, uzun süre bekledik.",
    "harika",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "korkunçtu",
    "memnun kaldım",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç beğenmedim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "efsane",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "mükemmel",
    "efsane",
    "mükemmel",
    "hiç memnun kalmadım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok iyiydi",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "berbat",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "mükemmel",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hayal kırıklığı",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç memnun kalmadım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok kötü",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok iyiydi",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "Servis çok yavaştı, uzun süre bekledik.",
    "mükemmel",
    "memnun kaldım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "efsane",
    "berbat",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "pişman oldum",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok iyiydi",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "hiç beğenmedim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "memnun kaldım",
    "beğendim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok sevdim",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "süper",
    "pişman oldum",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok sevdim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok sevdim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "süper",
    "harika",
    "beğendim",
    "hiç memnun kalmadım",
    "çok sevdim",
    "harika",
    "berbat",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok sevdim",
    "hiç memnun kalmadım",
    "memnun kaldım",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç beğenmedim",
    "harika",
    "berbat",
    "çok kötü",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "hiç memnun kalmadım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "harika",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hayal kırıklığı",
    "çok iyiydi",
    "çok sevdim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "berbat",
    "çok iyiydi",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç memnun kalmadım",
    "pişman oldum",
    "rezalet",
    "hiç beğenmedim",
    "çok sevdim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "berbat",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hayal kırıklığı",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "harika",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "memnun kaldım",
    "süper",
    "memnun kaldım",
    "çok iyiydi",
    "hiç beğenmedim",
    "çok sevdim",
    "beğendim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "rezalet",
    "çok kötü",
    "çok sevdim",
    "berbat",
    "memnun kaldım",
    "harika",
    "çok kötü",
    "beğendim",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "hiç beğenmedim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "rezalet",
    "memnun kaldım",
    "çok sevdim",
    "memnun kaldım",
    "çok iyiydi",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "rezalet",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "beğendim",
    "beğendim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "süper",
    "çok kötü",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "korkunçtu",
    "çok sevdim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok iyiydi",
    "korkunçtu",
    "beğendim",
    "memnun kaldım",
    "pişman oldum",
    "efsane",
    "mükemmel",
    "mükemmel",
    "süper",
    "memnun kaldım",
    "rezalet",
    "hiç beğenmedim",
    "hayal kırıklığı",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok sevdim",
    "hiç beğenmedim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "memnun kaldım",
    "efsane",
    "korkunçtu",
    "beğendim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok kötü",
    "berbat",
    "çok kötü",
    "hayal kırıklığı",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok kötü",
    "efsane",
    "harika",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "memnun kaldım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "süper",
    "hiç beğenmedim",
    "rezalet",
    "hiç beğenmedim",
    "çok sevdim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "beğendim",
    "hayal kırıklığı",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hayal kırıklığı",
    "berbat",
    "efsane",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "mükemmel",
    "Servis çok yavaştı, uzun süre bekledik.",
    "rezalet",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "mükemmel",
    "memnun kaldım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "harika",
    "hayal kırıklığı",
    "rezalet",
    "beğendim",
    "memnun kaldım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "korkunçtu",
    "rezalet",
    "çok kötü",
    "mükemmel",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "berbat",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok kötü",
    "mükemmel",
    "efsane",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "memnun kaldım",
    "efsane",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "hiç memnun kalmadım",
    "hayal kırıklığı",
    "çok kötü",
    "çok sevdim",
    "hiç beğenmedim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok iyiydi",
    "memnun kaldım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "pişman oldum",
    "berbat",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "süper",
    "mükemmel",
    "beğendim",
    "çok iyiydi",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hayal kırıklığı",
    "rezalet",
    "berbat",
    "korkunçtu",
    "korkunçtu",
    "süper",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "çok iyiydi",
    "pişman oldum",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "rezalet",
    "süper",
    "efsane",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "berbat",
    "mükemmel",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "harika",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "korkunçtu",
    "berbat",
    "hiç memnun kalmadım",
    "çok kötü",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "beğendim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "efsane",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok sevdim",
    "hayal kırıklığı",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "süper",
    "berbat",
    "harika",
    "memnun kaldım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "beğendim",
    "hiç memnun kalmadım",
    "beğendim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok sevdim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hayal kırıklığı",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "beğendim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç memnun kalmadım",
    "çok iyiydi",
    "pişman oldum",
    "pişman oldum",
    "harika",
    "rezalet",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "efsane",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "harika",
    "beğendim",
    "beğendim",
    "çok iyiydi",
    "beğendim",
    "hayal kırıklığı",
    "efsane",
    "süper",
    "hiç beğenmedim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "pişman oldum",
    "beğendim",
    "süper",
    "harika",
    "pişman oldum",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç beğenmedim",
    "mükemmel",
    "korkunçtu",
    "berbat",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "memnun kaldım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç beğenmedim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hiç beğenmedim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok kötü",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hayal kırıklığı",
    "çok kötü",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "berbat",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok iyiydi",
    "Servis çok yavaştı, uzun süre bekledik.",
    "süper",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "harika",
    "berbat",
    "berbat",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "berbat",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "berbat",
    "hayal kırıklığı",
    "memnun kaldım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok iyiydi",
    "çok sevdim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok iyiydi",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok sevdim",
    "berbat",
    "Servis çok yavaştı, uzun süre bekledik.",
    "pişman oldum",
    "beğendim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "rezalet",
    "harika",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "memnun kaldım",
    "pişman oldum",
    "pişman oldum",
    "berbat",
    "rezalet",
    "berbat",
    "hiç beğenmedim",
    "çok sevdim",
    "çok iyiydi",
    "berbat",
    "pişman oldum",
    "pişman oldum",
    "çok iyiydi",
    "pişman oldum",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "rezalet",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "rezalet",
    "çok sevdim",
    "çok kötü",
    "hiç memnun kalmadım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "efsane",
    "harika",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok kötü",
    "pişman oldum",
    "hayal kırıklığı",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "mükemmel",
    "efsane",
    "efsane",
    "mükemmel",
    "harika",
    "hayal kırıklığı",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "hayal kırıklığı",
    "berbat",
    "rezalet",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "berbat",
    "beğendim",
    "pişman oldum",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "pişman oldum",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "rezalet",
    "berbat",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "süper",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "pişman oldum",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hayal kırıklığı",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok iyiydi",
    "harika",
    "hiç beğenmedim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok kötü",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "beğendim",
    "mükemmel",
    "efsane",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "berbat",
    "efsane",
    "çok sevdim",
    "beğendim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "harika",
    "çok sevdim",
    "hiç memnun kalmadım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok iyiydi",
    "rezalet",
    "hiç beğenmedim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hayal kırıklığı",
    "süper",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "beğendim",
    "pişman oldum",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok sevdim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "harika",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "mükemmel",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç memnun kalmadım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "beğendim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "beğendim",
    "memnun kaldım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "mükemmel",
    "berbat",
    "korkunçtu",
    "rezalet",
    "harika",
    "beğendim",
    "hiç memnun kalmadım",
    "hiç memnun kalmadım",
    "çok iyiydi",
    "pişman oldum",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "korkunçtu",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok sevdim",
    "memnun kaldım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "süper",
    "berbat",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "rezalet",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "süper",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç memnun kalmadım",
    "rezalet",
    "çok kötü",
    "rezalet",
    "beğendim",
    "hayal kırıklığı",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "mükemmel",
    "çok kötü",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "rezalet",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "efsane",
    "mükemmel",
    "berbat",
    "mükemmel",
    "pişman oldum",
    "süper",
    "hayal kırıklığı",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "hayal kırıklığı",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "berbat",
    "süper",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "memnun kaldım",
    "hiç beğenmedim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç beğenmedim",
    "beğendim",
    "memnun kaldım",
    "çok sevdim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok iyiydi",
    "hiç beğenmedim",
    "rezalet",
    "beğendim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "beğendim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "mükemmel",
    "berbat",
    "çok kötü",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hiç memnun kalmadım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç memnun kalmadım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok sevdim",
    "korkunçtu",
    "rezalet",
    "mükemmel",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "süper",
    "çok sevdim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "pişman oldum",
    "hiç memnun kalmadım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "süper",
    "çok kötü",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok kötü",
    "pişman oldum",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok kötü",
    "beğendim",
    "rezalet",
    "korkunçtu",
    "çok sevdim",
    "hiç beğenmedim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "pişman oldum",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç memnun kalmadım",
    "pişman oldum",
    "çok kötü",
    "çok iyiydi",
    "berbat",
    "Servis çok yavaştı, uzun süre bekledik.",
    "efsane",
    "memnun kaldım",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "hiç memnun kalmadım",
    "rezalet",
    "hiç beğenmedim",
    "berbat",
    "hiç beğenmedim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok kötü",
    "harika",
    "korkunçtu",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok iyiydi",
    "çok sevdim",
    "süper",
    "rezalet",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok kötü",
    "korkunçtu",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "efsane",
    "çok kötü",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "mükemmel",
    "rezalet",
    "korkunçtu",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç memnun kalmadım",
    "hiç beğenmedim",
    "mükemmel",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "pişman oldum",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "berbat",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "memnun kaldım",
    "çok kötü",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç memnun kalmadım",
    "efsane",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok sevdim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "berbat",
    "memnun kaldım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "memnun kaldım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç beğenmedim",
    "mükemmel",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok sevdim",
    "hiç memnun kalmadım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hayal kırıklığı",
    "rezalet",
    "hiç beğenmedim",
    "süper",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok sevdim",
    "korkunçtu",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok iyiydi",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "berbat",
    "süper",
    "berbat",
    "rezalet",
    "hiç memnun kalmadım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "mükemmel",
    "çok sevdim",
    "beğendim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "pişman oldum",
    "çok kötü",
    "çok kötü",
    "hiç memnun kalmadım",
    "efsane",
    "pişman oldum",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "harika",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok iyiydi",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok kötü",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hayal kırıklığı",
    "pişman oldum",
    "rezalet",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "beğendim",
    "çok kötü",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "süper",
    "korkunçtu",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "memnun kaldım",
    "süper",
    "rezalet",
    "hiç beğenmedim",
    "efsane",
    "pişman oldum",
    "korkunçtu",
    "memnun kaldım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok sevdim",
    "çok kötü",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hayal kırıklığı",
    "mükemmel",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hayal kırıklığı",
    "süper",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç beğenmedim",
    "hiç memnun kalmadım",
    "mükemmel",
    "memnun kaldım",
    "hiç memnun kalmadım",
    "berbat",
    "efsane",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "korkunçtu",
    "rezalet",
    "beğendim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "beğendim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "memnun kaldım",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "rezalet",
    "çok sevdim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "korkunçtu",
    "süper",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç memnun kalmadım",
    "çok sevdim",
    "hayal kırıklığı",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "berbat",
    "süper",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "beğendim",
    "korkunçtu",
    "harika",
    "hiç memnun kalmadım",
    "çok sevdim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok kötü",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "süper",
    "korkunçtu",
    "mükemmel",
    "mükemmel",
    "mükemmel",
    "hiç memnun kalmadım",
    "çok sevdim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "korkunçtu",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "süper",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "süper",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "beğendim",
    "hiç beğenmedim",
    "mükemmel",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "korkunçtu",
    "hiç beğenmedim",
    "hiç memnun kalmadım",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hayal kırıklığı",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "mükemmel",
    "çok sevdim",
    "harika",
    "hiç memnun kalmadım",
    "beğendim",
    "beğendim",
    "pişman oldum",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hayal kırıklığı",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "pişman oldum",
    "rezalet",
    "rezalet",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "harika",
    "harika",
    "pişman oldum",
    "Servis çok yavaştı, uzun süre bekledik.",
    "mükemmel",
    "harika",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "harika",
    "beğendim",
    "çok iyiydi",
    "çok sevdim",
    "memnun kaldım",
    "harika",
    "pişman oldum",
    "çok kötü",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hayal kırıklığı",
    "rezalet",
    "rezalet",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "süper",
    "harika",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "korkunçtu",
    "memnun kaldım",
    "mükemmel",
    "rezalet",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "mükemmel",
    "korkunçtu",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "rezalet",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "berbat",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "korkunçtu",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok iyiydi",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "beğendim",
    "çok iyiydi",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok kötü",
    "hiç memnun kalmadım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "harika",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "pişman oldum",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "rezalet",
    "çok kötü",
    "harika",
    "hiç memnun kalmadım",
    "çok iyiydi",
    "memnun kaldım",
    "memnun kaldım",
    "çok sevdim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "süper",
    "hiç memnun kalmadım",
    "çok iyiydi",
    "hiç beğenmedim",
    "çok kötü",
    "çok iyiydi",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok iyiydi",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "efsane",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "efsane",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "süper",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok iyiydi",
    "beğendim",
    "efsane",
    "hayal kırıklığı",
    "çok iyiydi",
    "berbat",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "beğendim",
    "süper",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "harika",
    "çok sevdim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hayal kırıklığı",
    "çok kötü",
    "çok iyiydi",
    "pişman oldum",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç memnun kalmadım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "korkunçtu",
    "mükemmel",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hayal kırıklığı",
    "efsane",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "mükemmel",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "rezalet",
    "çok iyiydi",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok iyiydi",
    "pişman oldum",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "harika",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "beğendim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "efsane",
    "hiç beğenmedim",
    "korkunçtu",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "beğendim",
    "rezalet",
    "memnun kaldım",
    "hiç memnun kalmadım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç memnun kalmadım",
    "süper",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "beğendim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "pişman oldum",
    "hayal kırıklığı",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "süper",
    "rezalet",
    "efsane",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "beğendim",
    "harika",
    "harika",
    "harika",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "efsane",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "rezalet",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "rezalet",
    "beğendim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç beğenmedim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "süper",
    "hayal kırıklığı",
    "beğendim",
    "berbat",
    "çok kötü",
    "çok sevdim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok sevdim",
    "süper",
    "memnun kaldım",
    "çok kötü",
    "harika",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "harika",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç memnun kalmadım",
    "rezalet",
    "mükemmel",
    "süper",
    "efsane",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "memnun kaldım",
    "memnun kaldım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "korkunçtu",
    "rezalet",
    "efsane",
    "rezalet",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok kötü",
    "harika",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "korkunçtu",
    "hiç beğenmedim",
    "efsane",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "harika",
    "çok sevdim",
    "hayal kırıklığı",
    "hiç memnun kalmadım",
    "korkunçtu",
    "berbat",
    "korkunçtu",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "süper",
    "rezalet",
    "hayal kırıklığı",
    "memnun kaldım",
    "hiç beğenmedim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "pişman oldum",
    "rezalet",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "çok sevdim",
    "mükemmel",
    "rezalet",
    "hiç memnun kalmadım",
    "efsane",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "efsane",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "hiç memnun kalmadım",
    "berbat",
    "süper",
    "hiç beğenmedim",
    "hayal kırıklığı",
    "süper",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "pişman oldum",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "rezalet",
    "hiç memnun kalmadım",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "rezalet",
    "efsane",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "memnun kaldım",
    "korkunçtu",
    "hayal kırıklığı",
    "çok kötü",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "memnun kaldım",
    "hiç memnun kalmadım",
    "hiç beğenmedim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç beğenmedim",
    "hayal kırıklığı",
    "pişman oldum",
    "beğendim",
    "beğendim",
    "rezalet",
    "pişman oldum",
    "hiç beğenmedim",
    "hiç memnun kalmadım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "süper",
    "berbat",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "hayal kırıklığı",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok sevdim",
    "beğendim",
    "çok iyiydi",
    "berbat",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok sevdim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç beğenmedim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç beğenmedim",
    "mükemmel",
    "memnun kaldım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "mükemmel",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "beğendim",
    "çok sevdim",
    "hiç beğenmedim",
    "çok iyiydi",
    "hayal kırıklığı",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç memnun kalmadım",
    "pişman oldum",
    "beğendim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "korkunçtu",
    "çok iyiydi",
    "berbat",
    "efsane",
    "çok kötü",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "pişman oldum",
    "pişman oldum",
    "çok iyiydi",
    "çok kötü",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "korkunçtu",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "harika",
    "hiç memnun kalmadım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "pişman oldum",
    "korkunçtu",
    "süper",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hiç beğenmedim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "çok kötü",
    "berbat",
    "çok kötü",
    "berbat",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok iyiydi",
    "çok iyiydi",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hayal kırıklığı",
    "pişman oldum",
    "çok kötü",
    "hiç beğenmedim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "memnun kaldım",
    "efsane",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "memnun kaldım",
    "efsane",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok kötü",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hayal kırıklığı",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "rezalet",
    "memnun kaldım",
    "çok sevdim",
    "beğendim",
    "efsane",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç beğenmedim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "mükemmel",
    "süper",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "berbat",
    "memnun kaldım",
    "çok sevdim",
    "süper",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "süper",
    "harika",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "berbat",
    "çok sevdim",
    "çok iyiydi",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "harika",
    "berbat",
    "memnun kaldım",
    "harika",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hayal kırıklığı",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "berbat",
    "süper",
    "çok sevdim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok kötü",
    "çok sevdim",
    "hayal kırıklığı",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "berbat",
    "harika",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "beğendim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hiç memnun kalmadım",
    "memnun kaldım",
    "hiç memnun kalmadım",
    "hayal kırıklığı",
    "hiç beğenmedim",
    "berbat",
    "rezalet",
    "hiç memnun kalmadım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "pişman oldum",
    "harika",
    "mükemmel",
    "hiç beğenmedim",
    "hiç beğenmedim",
    "mükemmel",
    "süper",
    "mükemmel",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok sevdim",
    "beğendim",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "rezalet",
    "hiç memnun kalmadım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok iyiydi",
    "süper",
    "rezalet",
    "hiç beğenmedim",
    "korkunçtu",
    "süper",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç beğenmedim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok sevdim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "rezalet",
    "efsane",
    "çok sevdim",
    "rezalet",
    "harika",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok kötü",
    "hiç beğenmedim",
    "harika",
    "çok iyiydi",
    "süper",
    "efsane",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç memnun kalmadım",
    "berbat",
    "çok kötü",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hayal kırıklığı",
    "çok kötü",
    "mükemmel",
    "hiç memnun kalmadım",
    "çok kötü",
    "efsane",
    "efsane",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "mükemmel",
    "hiç beğenmedim",
    "mükemmel",
    "hiç memnun kalmadım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok sevdim",
    "hiç beğenmedim",
    "efsane",
    "hiç beğenmedim",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "efsane",
    "çok kötü",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "çok kötü",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "pişman oldum",
    "beğendim",
    "korkunçtu",
    "rezalet",
    "efsane",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "pişman oldum",
    "berbat",
    "çok kötü",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "korkunçtu",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "beğendim",
    "hiç beğenmedim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "memnun kaldım",
    "beğendim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "memnun kaldım",
    "hayal kırıklığı",
    "korkunçtu",
    "hayal kırıklığı",
    "memnun kaldım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "rezalet",
    "mükemmel",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hayal kırıklığı",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç beğenmedim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "mükemmel",
    "Servis çok yavaştı, uzun süre bekledik.",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "memnun kaldım",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "çok kötü",
    "harika",
    "beğendim",
    "mükemmel",
    "çok kötü",
    "çok kötü",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "pişman oldum",
    "çok kötü",
    "çok sevdim",
    "beğendim",
    "rezalet",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "çok iyiydi",
    "korkunçtu",
    "çok iyiydi",
    "memnun kaldım",
    "çok sevdim",
    "mükemmel",
    "Servis çok yavaştı, uzun süre bekledik.",
    "efsane",
    "çok sevdim",
    "çok iyiydi",
    "rezalet",
    "çok kötü",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç memnun kalmadım",
    "hiç memnun kalmadım",
    "çok kötü",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "pişman oldum",
    "efsane",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "süper",
    "hiç beğenmedim",
    "efsane",
    "çok kötü",
    "Servis çok yavaştı, uzun süre bekledik.",
    "rezalet",
    "berbat",
    "Servis çok yavaştı, uzun süre bekledik.",
    "beğendim",
    "hiç memnun kalmadım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "pişman oldum",
    "memnun kaldım",
    "korkunçtu",
    "harika",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "pişman oldum",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "memnun kaldım",
    "çok sevdim",
    "süper",
    "rezalet",
    "hayal kırıklığı",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "çok sevdim",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "korkunçtu",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "hiç memnun kalmadım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "çok iyiydi",
    "çok iyiydi",
    "çok kötü",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "harika",
    "çok kötü",
    "harika",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "korkunçtu",
    "süper",
    "mükemmel",
    "hiç beğenmedim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "beğendim",
    "pişman oldum",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok kötü",
    "hiç beğenmedim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "mükemmel",
    "hayal kırıklığı",
    "çok iyiydi",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "beğendim",
    "süper",
    "korkunçtu",
    "efsane",
    "hiç beğenmedim",
    "harika",
    "pişman oldum",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "hiç memnun kalmadım",
    "hiç memnun kalmadım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "beğendim",
    "efsane",
    "çok kötü",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok iyiydi",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "hayal kırıklığı",
    "çok sevdim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "hiç memnun kalmadım",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "beğendim",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "rezalet",
    "hiç memnun kalmadım",
    "çok sevdim",
    "süper",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "memnun kaldım",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok sevdim",
    "memnun kaldım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "pişman oldum",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "korkunçtu",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "hiç memnun kalmadım",
    "Servis çok yavaştı, uzun süre bekledik.",
    "beğendim",
    "harika",
    "çok sevdim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç beğenmedim",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "efsane",
    "Servis çok yavaştı, uzun süre bekledik.",
    "çok sevdim",
    "hayal kırıklığı",
    "hiç beğenmedim",
    "efsane",
    "efsane",
    "çok kötü",
    "çok iyiydi",
    "harika",
    "hayal kırıklığı",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "efsane",
    "süper",
    "memnun kaldım",
    "süper",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "rezalet",
    "memnun kaldım",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "pişman oldum",
    "pişman oldum",
    "hiç memnun kalmadım",
    "çok sevdim",
    "pişman oldum",
    "berbat",
    "süper",
    "hiç memnun kalmadım",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç beğenmedim",
    "korkunçtu",
    "harika",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "Ambiyans çok hoştu, keyifli bir akşam geçirdik.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "çok iyiydi",
    "hiç memnun kalmadım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "berbat",
    "rezalet",
    "harika",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "hayal kırıklığı",
    "efsane",
    "çok iyiydi",
    "çok sevdim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "harika",
    "hayal kırıklığı",
    "hiç beğenmedim",
    "hiç memnun kalmadım",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "mükemmel",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "çok sevdim",
    "rezalet",
    "efsane",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "efsane",
    "rezalet",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "berbat",
    "hiç memnun kalmadım",
    "çok iyiydi",
    "hiç memnun kalmadım",
    "çok sevdim",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "mükemmel",
    "hiç beğenmedim",
    "hayal kırıklığı",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "beğendim",
    "korkunçtu",
    "hayal kırıklığı",
    "hayal kırıklığı",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "harika",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "korkunçtu",
    "süper",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "beğendim",
    "çok kötü",
    "efsane",
    "hiç beğenmedim",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "berbat",
    "pişman oldum",
    "Yemekler harikaydı, tekrar gelmek isterim.",
    "Servis çok yavaştı, uzun süre bekledik.",
    "efsane",
    "çok kötü",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "beğendim",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "hiç beğenmedim",
    "Ortam çok gürültülüydü, rahatsız ediciydi.",
    "çok iyiydi",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "Yemekler çok soğuktu, hiç memnun kalmadım.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Servis çok iyiydi, garsonlar güler yüzlüydü.",
    "hiç memnun kalmadım",
    "çok iyiydi",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Yemeklerin tadı tuzu yoktu, beğenmedim.",
    "Garsonlar ilgisizdi, siparişim yanlış geldi.",
    "korkunçtu",
    "çok sevdim",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "harika",
    "rezalet",
    "memnun kaldım",
    "memnun kaldım",
    "berbat",
    "Tatlılar efsaneydi, özellikle cheesecake çok iyiydi.",
    "süper",
    "Her şey mükemmeldi, teşekkür ederiz.",
    "çok sevdim",
        "tadı berbattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "harikaydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok lezzetli",
    "çok vasattı",
    "çok lezzetli",
    "yemek geç geldi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "kesinlikle tekrar gelirim",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "bayıldım",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok vasattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "güler yüzlü hizmet",
    "çok lezzetli",
    "hiç hoşuma gitmedi",
    "masamız çok kirliydi",
    "yemek geç geldi",
    "çok lezzetli",
    "masamız çok kirliydi",
    "temiz ve hızlıydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok rahatsız ediciydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok lezzetli",
    "temiz ve hızlıydı",
    "çok vasattı",
    "ailece çok sevdik",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "güler yüzlü hizmet",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "masamız çok kirliydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "harikaydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "hiç hoşuma gitmedi",
    "bayıldım",
    "tam kıvamında",
    "kesinlikle tekrar gelirim",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok lezzetli",
    "hiç hoşuma gitmedi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "harikaydı",
    "ailece çok sevdik",
    "yavaş ve ilgisiz",
    "tam kıvamında",
    "Yemek geç geldi ve sıcak değildi.",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "ailece çok sevdik",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "temiz ve hızlıydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "bayıldım",
    "kesinlikle tekrar gelirim",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok vasattı",
    "masamız çok kirliydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "kesinlikle tekrar gelirim",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "güler yüzlü hizmet",
    "çok lezzetli",
    "yavaş ve ilgisiz",
    "temiz ve hızlıydı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok rahatsız ediciydi",
    "çok rahatsız ediciydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yavaş ve ilgisiz",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok lezzetli",
    "tadı berbattı",
    "fiyatlar gereksiz pahalı",
    "tadı berbattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yavaş ve ilgisiz",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "fiyatlar gereksiz pahalı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "tam kıvamında",
    "çok lezzetli",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "temiz ve hızlıydı",
    "harikaydı",
    "hiç hoşuma gitmedi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tadı berbattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "kesinlikle tekrar gelirim",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "hiç hoşuma gitmedi",
    "tadı berbattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yavaş ve ilgisiz",
    "temiz ve hızlıydı",
    "çok lezzetli",
    "harikaydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "masamız çok kirliydi",
    "güler yüzlü hizmet",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "temiz ve hızlıydı",
    "çok vasattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "harikaydı",
    "hiç hoşuma gitmedi",
    "temiz ve hızlıydı",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "çok vasattı",
    "çok vasattı",
    "çok lezzetli",
    "tam kıvamında",
    "fiyatlar gereksiz pahalı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yemek geç geldi",
    "ailece çok sevdik",
    "temiz ve hızlıydı",
    "hiç hoşuma gitmedi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "yavaş ve ilgisiz",
    "tam kıvamında",
    "yemek geç geldi",
    "kesinlikle tekrar gelirim",
    "masamız çok kirliydi",
    "tam kıvamında",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "ailece çok sevdik",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "güler yüzlü hizmet",
    "yavaş ve ilgisiz",
    "harikaydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok lezzetli",
    "kesinlikle tekrar gelirim",
    "masamız çok kirliydi",
    "fiyatlar gereksiz pahalı",
    "tam kıvamında",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tam kıvamında",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yavaş ve ilgisiz",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "çok lezzetli",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "temiz ve hızlıydı",
    "yavaş ve ilgisiz",
    "çok lezzetli",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "güler yüzlü hizmet",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok vasattı",
    "yavaş ve ilgisiz",
    "tadı berbattı",
    "tam kıvamında",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "fiyatlar gereksiz pahalı",
    "masamız çok kirliydi",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "fiyatlar gereksiz pahalı",
    "bayıldım",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok rahatsız ediciydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "harikaydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "ailece çok sevdik",
    "yavaş ve ilgisiz",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "masamız çok kirliydi",
    "bayıldım",
    "hiç hoşuma gitmedi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "bayıldım",
    "masamız çok kirliydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "masamız çok kirliydi",
    "fiyatlar gereksiz pahalı",
    "harikaydı",
    "çok vasattı",
    "hiç hoşuma gitmedi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "harikaydı",
    "tadı berbattı",
    "Yemek geç geldi ve sıcak değildi.",
    "yavaş ve ilgisiz",
    "temiz ve hızlıydı",
    "fiyatlar gereksiz pahalı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "temiz ve hızlıydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "bayıldım",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "bayıldım",
    "kesinlikle tekrar gelirim",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "bayıldım",
    "tadı berbattı",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "yavaş ve ilgisiz",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "ailece çok sevdik",
    "masamız çok kirliydi",
    "temiz ve hızlıydı",
    "yavaş ve ilgisiz",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "hiç hoşuma gitmedi",
    "çok lezzetli",
    "bayıldım",
    "temiz ve hızlıydı",
    "hiç hoşuma gitmedi",
    "Yemek geç geldi ve sıcak değildi.",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "Yemek geç geldi ve sıcak değildi.",
    "çok lezzetli",
    "kesinlikle tekrar gelirim",
    "bayıldım",
    "yemek geç geldi",
    "çok vasattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "tam kıvamında",
    "tam kıvamında",
    "temiz ve hızlıydı",
    "bayıldım",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "kesinlikle tekrar gelirim",
    "güler yüzlü hizmet",
    "güler yüzlü hizmet",
    "fiyatlar gereksiz pahalı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "kesinlikle tekrar gelirim",
    "hiç hoşuma gitmedi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tadı berbattı",
    "ailece çok sevdik",
    "tadı berbattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "çok rahatsız ediciydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tadı berbattı",
    "harikaydı",
    "hiç hoşuma gitmedi",
    "temiz ve hızlıydı",
    "çok lezzetli",
    "ailece çok sevdik",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "bayıldım",
    "çok vasattı",
    "tadı berbattı",
    "kesinlikle tekrar gelirim",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok lezzetli",
    "bayıldım",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yemek geç geldi",
    "çok rahatsız ediciydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok rahatsız ediciydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok lezzetli",
    "çok vasattı",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok lezzetli",
    "temiz ve hızlıydı",
    "çok vasattı",
    "masamız çok kirliydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok vasattı",
    "tam kıvamında",
    "ailece çok sevdik",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "harikaydı",
    "çok vasattı",
    "hiç hoşuma gitmedi",
    "fiyatlar gereksiz pahalı",
    "yemek geç geldi",
    "Yemek geç geldi ve sıcak değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "temiz ve hızlıydı",
    "temiz ve hızlıydı",
    "Yemek geç geldi ve sıcak değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "tadı berbattı",
    "kesinlikle tekrar gelirim",
    "yemek geç geldi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "ailece çok sevdik",
    "hiç hoşuma gitmedi",
    "çok lezzetli",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "fiyatlar gereksiz pahalı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "kesinlikle tekrar gelirim",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "masamız çok kirliydi",
    "masamız çok kirliydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yemek geç geldi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "harikaydı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Yemek geç geldi ve sıcak değildi.",
    "masamız çok kirliydi",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "kesinlikle tekrar gelirim",
    "yemek geç geldi",
    "kesinlikle tekrar gelirim",
    "tam kıvamında",
    "temiz ve hızlıydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "temiz ve hızlıydı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "güler yüzlü hizmet",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tam kıvamında",
    "yemek geç geldi",
    "çok vasattı",
    "çok vasattı",
    "çok vasattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "ailece çok sevdik",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "fiyatlar gereksiz pahalı",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "hiç hoşuma gitmedi",
    "çok vasattı",
    "bayıldım",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "masamız çok kirliydi",
    "Yemek geç geldi ve sıcak değildi.",
    "çok rahatsız ediciydi",
    "hiç hoşuma gitmedi",
    "harikaydı",
    "yemek geç geldi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "bayıldım",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "bayıldım",
    "ailece çok sevdik",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "kesinlikle tekrar gelirim",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "temiz ve hızlıydı",
    "yemek geç geldi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "masamız çok kirliydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tadı berbattı",
    "Yemek geç geldi ve sıcak değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "kesinlikle tekrar gelirim",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "temiz ve hızlıydı",
    "çok vasattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "tam kıvamında",
    "yavaş ve ilgisiz",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "kesinlikle tekrar gelirim",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "güler yüzlü hizmet",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "masamız çok kirliydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "temiz ve hızlıydı",
    "yemek geç geldi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok vasattı",
    "tadı berbattı",
    "masamız çok kirliydi",
    "hiç hoşuma gitmedi",
    "Yemek geç geldi ve sıcak değildi.",
    "yavaş ve ilgisiz",
    "temiz ve hızlıydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yemek geç geldi",
    "kesinlikle tekrar gelirim",
    "çok rahatsız ediciydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "masamız çok kirliydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "bayıldım",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "ailece çok sevdik",
    "tadı berbattı",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "bayıldım",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok rahatsız ediciydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemek geç geldi ve sıcak değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "fiyatlar gereksiz pahalı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tam kıvamında",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok rahatsız ediciydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "çok lezzetli",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "masamız çok kirliydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "tadı berbattı",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok lezzetli",
    "güler yüzlü hizmet",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "hiç hoşuma gitmedi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "bayıldım",
    "bayıldım",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "kesinlikle tekrar gelirim",
    "yemek geç geldi",
    "çok vasattı",
    "harikaydı",
    "çok lezzetli",
    "bayıldım",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "güler yüzlü hizmet",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yemek geç geldi",
    "tadı berbattı",
    "yemek geç geldi",
    "harikaydı",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yavaş ve ilgisiz",
    "çok vasattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "tam kıvamında",
    "kesinlikle tekrar gelirim",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "kesinlikle tekrar gelirim",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "yemek geç geldi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "masamız çok kirliydi",
    "tadı berbattı",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "çok lezzetli",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yavaş ve ilgisiz",
    "Yemek geç geldi ve sıcak değildi.",
    "çok rahatsız ediciydi",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "tadı berbattı",
    "çok lezzetli",
    "yemek geç geldi",
    "Yemek geç geldi ve sıcak değildi.",
    "güler yüzlü hizmet",
    "çok lezzetli",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "çok rahatsız ediciydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "masamız çok kirliydi",
    "masamız çok kirliydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "güler yüzlü hizmet",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "harikaydı",
    "tadı berbattı",
    "çok lezzetli",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "güler yüzlü hizmet",
    "tam kıvamında",
    "tam kıvamında",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yavaş ve ilgisiz",
    "masamız çok kirliydi",
    "tam kıvamında",
    "fiyatlar gereksiz pahalı",
    "güler yüzlü hizmet",
    "tadı berbattı",
    "güler yüzlü hizmet",
    "çok vasattı",
    "temiz ve hızlıydı",
    "temiz ve hızlıydı",
    "yemek geç geldi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok vasattı",
    "fiyatlar gereksiz pahalı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yemek geç geldi",
    "Yemek geç geldi ve sıcak değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yemek geç geldi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "temiz ve hızlıydı",
    "masamız çok kirliydi",
    "güler yüzlü hizmet",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "çok vasattı",
    "Yemek geç geldi ve sıcak değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemek geç geldi ve sıcak değildi.",
    "masamız çok kirliydi",
    "yavaş ve ilgisiz",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok vasattı",
    "çok vasattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "yavaş ve ilgisiz",
    "fiyatlar gereksiz pahalı",
    "hiç hoşuma gitmedi",
    "temiz ve hızlıydı",
    "ailece çok sevdik",
    "fiyatlar gereksiz pahalı",
    "Yemek geç geldi ve sıcak değildi.",
    "ailece çok sevdik",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "yavaş ve ilgisiz",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "Yemek geç geldi ve sıcak değildi.",
    "harikaydı",
    "güler yüzlü hizmet",
    "çok lezzetli",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yavaş ve ilgisiz",
    "masamız çok kirliydi",
    "yavaş ve ilgisiz",
    "fiyatlar gereksiz pahalı",
    "bayıldım",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tadı berbattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tadı berbattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok rahatsız ediciydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "harikaydı",
    "çok vasattı",
    "tadı berbattı",
    "temiz ve hızlıydı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yavaş ve ilgisiz",
    "masamız çok kirliydi",
    "tam kıvamında",
    "Yemek geç geldi ve sıcak değildi.",
    "kesinlikle tekrar gelirim",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok rahatsız ediciydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok lezzetli",
    "güler yüzlü hizmet",
    "harikaydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "masamız çok kirliydi",
    "tadı berbattı",
    "harikaydı",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "bayıldım",
    "kesinlikle tekrar gelirim",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tadı berbattı",
    "çok rahatsız ediciydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "temiz ve hızlıydı",
    "yavaş ve ilgisiz",
    "temiz ve hızlıydı",
    "çok rahatsız ediciydi",
    "kesinlikle tekrar gelirim",
    "tam kıvamında",
    "Yemek geç geldi ve sıcak değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "yavaş ve ilgisiz",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemek geç geldi ve sıcak değildi.",
    "hiç hoşuma gitmedi",
    "güler yüzlü hizmet",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "harikaydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "bayıldım",
    "masamız çok kirliydi",
    "güler yüzlü hizmet",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "kesinlikle tekrar gelirim",
    "masamız çok kirliydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "masamız çok kirliydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yavaş ve ilgisiz",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "masamız çok kirliydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "bayıldım",
    "bayıldım",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok rahatsız ediciydi",
    "kesinlikle tekrar gelirim",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "ailece çok sevdik",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "temiz ve hızlıydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yemek geç geldi",
    "ailece çok sevdik",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "güler yüzlü hizmet",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yavaş ve ilgisiz",
    "yavaş ve ilgisiz",
    "bayıldım",
    "tadı berbattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok rahatsız ediciydi",
    "bayıldım",
    "güler yüzlü hizmet",
    "tadı berbattı",
    "yemek geç geldi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "masamız çok kirliydi",
    "yavaş ve ilgisiz",
    "tam kıvamında",
    "çok lezzetli",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "fiyatlar gereksiz pahalı",
    "masamız çok kirliydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok vasattı",
    "tadı berbattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "tam kıvamında",
    "ailece çok sevdik",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yemek geç geldi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "kesinlikle tekrar gelirim",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "yemek geç geldi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yemek geç geldi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok vasattı",
    "tam kıvamında",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok vasattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "güler yüzlü hizmet",
    "masamız çok kirliydi",
    "harikaydı",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "harikaydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "tadı berbattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "bayıldım",
    "bayıldım",
    "Yemek geç geldi ve sıcak değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok lezzetli",
    "Yemek geç geldi ve sıcak değildi.",
    "güler yüzlü hizmet",
    "Yemek geç geldi ve sıcak değildi.",
    "harikaydı",
    "harikaydı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "bayıldım",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "masamız çok kirliydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok rahatsız ediciydi",
    "yemek geç geldi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok rahatsız ediciydi",
    "kesinlikle tekrar gelirim",
    "yavaş ve ilgisiz",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "güler yüzlü hizmet",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "tam kıvamında",
    "masamız çok kirliydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yavaş ve ilgisiz",
    "temiz ve hızlıydı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "Yemek geç geldi ve sıcak değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "harikaydı",
    "hiç hoşuma gitmedi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tam kıvamında",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Yemek geç geldi ve sıcak değildi.",
    "yavaş ve ilgisiz",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tadı berbattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yavaş ve ilgisiz",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "temiz ve hızlıydı",
    "yemek geç geldi",
    "masamız çok kirliydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tadı berbattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "yemek geç geldi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "kesinlikle tekrar gelirim",
    "hiç hoşuma gitmedi",
    "çok lezzetli",
    "fiyatlar gereksiz pahalı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "güler yüzlü hizmet",
    "tadı berbattı",
    "tadı berbattı",
    "masamız çok kirliydi",
    "masamız çok kirliydi",
    "çok vasattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok lezzetli",
    "tadı berbattı",
    "Yemek geç geldi ve sıcak değildi.",
    "güler yüzlü hizmet",
    "güler yüzlü hizmet",
    "tadı berbattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "bayıldım",
    "kesinlikle tekrar gelirim",
    "çok rahatsız ediciydi",
    "harikaydı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "güler yüzlü hizmet",
    "yavaş ve ilgisiz",
    "tadı berbattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "kesinlikle tekrar gelirim",
    "tam kıvamında",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "kesinlikle tekrar gelirim",
    "çok lezzetli",
    "fiyatlar gereksiz pahalı",
    "yavaş ve ilgisiz",
    "çok lezzetli",
    "güler yüzlü hizmet",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemek geç geldi ve sıcak değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "harikaydı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "bayıldım",
    "kesinlikle tekrar gelirim",
    "hiç hoşuma gitmedi",
    "yavaş ve ilgisiz",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "kesinlikle tekrar gelirim",
    "çok rahatsız ediciydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok rahatsız ediciydi",
    "çok lezzetli",
    "yemek geç geldi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "kesinlikle tekrar gelirim",
    "güler yüzlü hizmet",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "güler yüzlü hizmet",
    "harikaydı",
    "tadı berbattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yemek geç geldi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yavaş ve ilgisiz",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "masamız çok kirliydi",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "hiç hoşuma gitmedi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "ailece çok sevdik",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "güler yüzlü hizmet",
    "çok rahatsız ediciydi",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "harikaydı",
    "tam kıvamında",
    "ailece çok sevdik",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemek geç geldi ve sıcak değildi.",
    "tadı berbattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "harikaydı",
    "tadı berbattı",
    "yemek geç geldi",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "çok vasattı",
    "tam kıvamında",
    "çok rahatsız ediciydi",
    "yemek geç geldi",
    "çok vasattı",
    "kesinlikle tekrar gelirim",
    "tadı berbattı",
    "tam kıvamında",
    "Yemek geç geldi ve sıcak değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "temiz ve hızlıydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "harikaydı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "tam kıvamında",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "ailece çok sevdik",
    "harikaydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yavaş ve ilgisiz",
    "bayıldım",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "fiyatlar gereksiz pahalı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yavaş ve ilgisiz",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok rahatsız ediciydi",
    "bayıldım",
    "masamız çok kirliydi",
    "tadı berbattı",
    "bayıldım",
    "çok rahatsız ediciydi",
    "temiz ve hızlıydı",
    "güler yüzlü hizmet",
    "masamız çok kirliydi",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "hiç hoşuma gitmedi",
    "Yemek geç geldi ve sıcak değildi.",
    "yavaş ve ilgisiz",
    "tam kıvamında",
    "güler yüzlü hizmet",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "çok vasattı",
    "hiç hoşuma gitmedi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok vasattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "tam kıvamında",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemek geç geldi ve sıcak değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "hiç hoşuma gitmedi",
    "bayıldım",
    "tam kıvamında",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "kesinlikle tekrar gelirim",
    "yavaş ve ilgisiz",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok lezzetli",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "çok rahatsız ediciydi",
    "çok rahatsız ediciydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "ailece çok sevdik",
    "Yemek geç geldi ve sıcak değildi.",
    "tadı berbattı",
    "tadı berbattı",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yemek geç geldi",
    "kesinlikle tekrar gelirim",
    "masamız çok kirliydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "masamız çok kirliydi",
    "çok lezzetli",
    "Yemek geç geldi ve sıcak değildi.",
    "ailece çok sevdik",
    "tam kıvamında",
    "çok rahatsız ediciydi",
    "harikaydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yavaş ve ilgisiz",
    "tam kıvamında",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "güler yüzlü hizmet",
    "yavaş ve ilgisiz",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "yemek geç geldi",
    "yemek geç geldi",
    "tam kıvamında",
    "masamız çok kirliydi",
    "çok vasattı",
    "yavaş ve ilgisiz",
    "masamız çok kirliydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "fiyatlar gereksiz pahalı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok rahatsız ediciydi",
    "hiç hoşuma gitmedi",
    "hiç hoşuma gitmedi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "kesinlikle tekrar gelirim",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "bayıldım",
    "kesinlikle tekrar gelirim",
    "hiç hoşuma gitmedi",
    "hiç hoşuma gitmedi",
    "hiç hoşuma gitmedi",
    "ailece çok sevdik",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok lezzetli",
    "harikaydı",
    "çok lezzetli",
    "masamız çok kirliydi",
    "kesinlikle tekrar gelirim",
    "yavaş ve ilgisiz",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "masamız çok kirliydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok lezzetli",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yavaş ve ilgisiz",
    "tadı berbattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "fiyatlar gereksiz pahalı",
    "yemek geç geldi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "ailece çok sevdik",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yavaş ve ilgisiz",
    "tam kıvamında",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "tadı berbattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok lezzetli",
    "kesinlikle tekrar gelirim",
    "güler yüzlü hizmet",
    "yavaş ve ilgisiz",
    "masamız çok kirliydi",
    "tadı berbattı",
    "çok vasattı",
    "yemek geç geldi",
    "yemek geç geldi",
    "masamız çok kirliydi",
    "Yemek geç geldi ve sıcak değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "hiç hoşuma gitmedi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "yemek geç geldi",
    "çok lezzetli",
    "temiz ve hızlıydı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok rahatsız ediciydi",
    "tadı berbattı",
    "Yemek geç geldi ve sıcak değildi.",
    "tadı berbattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tam kıvamında",
    "çok lezzetli",
    "fiyatlar gereksiz pahalı",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "güler yüzlü hizmet",
    "güler yüzlü hizmet",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "fiyatlar gereksiz pahalı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yemek geç geldi",
    "Yemek geç geldi ve sıcak değildi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok lezzetli",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "bayıldım",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "çok vasattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok vasattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok rahatsız ediciydi",
    "hiç hoşuma gitmedi",
    "yavaş ve ilgisiz",
    "yavaş ve ilgisiz",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok rahatsız ediciydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "harikaydı",
    "çok rahatsız ediciydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "hiç hoşuma gitmedi",
    "yemek geç geldi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "harikaydı",
    "güler yüzlü hizmet",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "bayıldım",
    "Yemek geç geldi ve sıcak değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "masamız çok kirliydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok vasattı",
    "bayıldım",
    "ailece çok sevdik",
    "bayıldım",
    "güler yüzlü hizmet",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok rahatsız ediciydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "hiç hoşuma gitmedi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "yavaş ve ilgisiz",
    "güler yüzlü hizmet",
    "masamız çok kirliydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "fiyatlar gereksiz pahalı",
    "hiç hoşuma gitmedi",
    "çok lezzetli",
    "çok rahatsız ediciydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "masamız çok kirliydi",
    "çok vasattı",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "masamız çok kirliydi",
    "güler yüzlü hizmet",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "temiz ve hızlıydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "fiyatlar gereksiz pahalı",
    "güler yüzlü hizmet",
    "çok vasattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yavaş ve ilgisiz",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok lezzetli",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "yemek geç geldi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "kesinlikle tekrar gelirim",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yemek geç geldi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "tam kıvamında",
    "temiz ve hızlıydı",
    "fiyatlar gereksiz pahalı",
    "yavaş ve ilgisiz",
    "masamız çok kirliydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "masamız çok kirliydi",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok rahatsız ediciydi",
    "çok vasattı",
    "temiz ve hızlıydı",
    "tadı berbattı",
    "fiyatlar gereksiz pahalı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "bayıldım",
    "güler yüzlü hizmet",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok vasattı",
    "tam kıvamında",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "kesinlikle tekrar gelirim",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "bayıldım",
    "güler yüzlü hizmet",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok rahatsız ediciydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok lezzetli",
    "tam kıvamında",
    "harikaydı",
    "hiç hoşuma gitmedi",
    "kesinlikle tekrar gelirim",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemek geç geldi ve sıcak değildi.",
    "harikaydı",
    "kesinlikle tekrar gelirim",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "fiyatlar gereksiz pahalı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tadı berbattı",
    "çok rahatsız ediciydi",
    "harikaydı",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "kesinlikle tekrar gelirim",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "temiz ve hızlıydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok lezzetli",
    "hiç hoşuma gitmedi",
    "harikaydı",
    "temiz ve hızlıydı",
    "tadı berbattı",
    "hiç hoşuma gitmedi",
    "çok vasattı",
    "tadı berbattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "ailece çok sevdik",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "bayıldım",
    "temiz ve hızlıydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok lezzetli",
    "hiç hoşuma gitmedi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tam kıvamında",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tam kıvamında",
    "bayıldım",
    "tadı berbattı",
    "çok lezzetli",
    "çok vasattı",
    "çok vasattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok lezzetli",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "masamız çok kirliydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "güler yüzlü hizmet",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "ailece çok sevdik",
    "yavaş ve ilgisiz",
    "güler yüzlü hizmet",
    "yemek geç geldi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "kesinlikle tekrar gelirim",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "fiyatlar gereksiz pahalı",
    "harikaydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok rahatsız ediciydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "masamız çok kirliydi",
    "çok rahatsız ediciydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "çok lezzetli",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "fiyatlar gereksiz pahalı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "harikaydı",
    "yavaş ve ilgisiz",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "çok lezzetli",
    "bayıldım",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "hiç hoşuma gitmedi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok lezzetli",
    "Yemek geç geldi ve sıcak değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "hiç hoşuma gitmedi",
    "kesinlikle tekrar gelirim",
    "hiç hoşuma gitmedi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "temiz ve hızlıydı",
    "yavaş ve ilgisiz",
    "yavaş ve ilgisiz",
    "güler yüzlü hizmet",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "masamız çok kirliydi",
    "fiyatlar gereksiz pahalı",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "Yemek geç geldi ve sıcak değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok vasattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "masamız çok kirliydi",
    "fiyatlar gereksiz pahalı",
    "fiyatlar gereksiz pahalı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "temiz ve hızlıydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "tam kıvamında",
    "tam kıvamında",
    "harikaydı",
    "hiç hoşuma gitmedi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "hiç hoşuma gitmedi",
    "harikaydı",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok rahatsız ediciydi",
    "çok vasattı",
    "harikaydı",
    "masamız çok kirliydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok vasattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tam kıvamında",
    "ailece çok sevdik",
    "yemek geç geldi",
    "yavaş ve ilgisiz",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "güler yüzlü hizmet",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "bayıldım",
    "hiç hoşuma gitmedi",
    "masamız çok kirliydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "kesinlikle tekrar gelirim",
    "harikaydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tadı berbattı",
    "harikaydı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "bayıldım",
    "güler yüzlü hizmet",
    "kesinlikle tekrar gelirim",
    "bayıldım",
    "çok rahatsız ediciydi",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "harikaydı",
    "harikaydı",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "harikaydı",
    "tadı berbattı",
    "hiç hoşuma gitmedi",
    "yavaş ve ilgisiz",
    "bayıldım",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "ailece çok sevdik",
    "tadı berbattı",
    "çok vasattı",
    "çok lezzetli",
    "çok lezzetli",
    "bayıldım",
    "yemek geç geldi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok rahatsız ediciydi",
    "çok vasattı",
    "harikaydı",
    "tam kıvamında",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok lezzetli",
    "fiyatlar gereksiz pahalı",
    "tadı berbattı",
    "temiz ve hızlıydı",
    "temiz ve hızlıydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "masamız çok kirliydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "kesinlikle tekrar gelirim",
    "çok lezzetli",
    "tam kıvamında",
    "yavaş ve ilgisiz",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yavaş ve ilgisiz",
    "ailece çok sevdik",
    "bayıldım",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yavaş ve ilgisiz",
    "ailece çok sevdik",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "fiyatlar gereksiz pahalı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "hiç hoşuma gitmedi",
    "tadı berbattı",
    "çok rahatsız ediciydi",
    "yemek geç geldi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok rahatsız ediciydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok lezzetli",
    "Yemek geç geldi ve sıcak değildi.",
    "ailece çok sevdik",
    "çok rahatsız ediciydi",
    "hiç hoşuma gitmedi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "bayıldım",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "yemek geç geldi",
    "temiz ve hızlıydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok vasattı",
    "çok vasattı",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "bayıldım",
    "harikaydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "temiz ve hızlıydı",
    "çok lezzetli",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "temiz ve hızlıydı",
    "bayıldım",
    "harikaydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yavaş ve ilgisiz",
    "tam kıvamında",
    "çok rahatsız ediciydi",
    "fiyatlar gereksiz pahalı",
    "harikaydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "bayıldım",
    "kesinlikle tekrar gelirim",
    "fiyatlar gereksiz pahalı",
    "harikaydı",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yemek geç geldi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok lezzetli",
    "bayıldım",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "ailece çok sevdik",
    "hiç hoşuma gitmedi",
    "ailece çok sevdik",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "ailece çok sevdik",
    "güler yüzlü hizmet",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "bayıldım",
    "masamız çok kirliydi",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tam kıvamında",
    "çok vasattı",
    "çok lezzetli",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok lezzetli",
    "yavaş ve ilgisiz",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "fiyatlar gereksiz pahalı",
    "masamız çok kirliydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "kesinlikle tekrar gelirim",
    "yemek geç geldi",
    "bayıldım",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "hiç hoşuma gitmedi",
    "harikaydı",
    "tam kıvamında",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "fiyatlar gereksiz pahalı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yavaş ve ilgisiz",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "kesinlikle tekrar gelirim",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "Yemek geç geldi ve sıcak değildi.",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "kesinlikle tekrar gelirim",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "temiz ve hızlıydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "güler yüzlü hizmet",
    "tadı berbattı",
    "harikaydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok lezzetli",
    "bayıldım",
    "masamız çok kirliydi",
    "çok rahatsız ediciydi",
    "çok rahatsız ediciydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "fiyatlar gereksiz pahalı",
    "fiyatlar gereksiz pahalı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "harikaydı",
    "ailece çok sevdik",
    "tam kıvamında",
    "çok vasattı",
    "tadı berbattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok vasattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "temiz ve hızlıydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok rahatsız ediciydi",
    "tadı berbattı",
    "hiç hoşuma gitmedi",
    "tam kıvamında",
    "yemek geç geldi",
    "tadı berbattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "ailece çok sevdik",
    "çok lezzetli",
    "ailece çok sevdik",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "tam kıvamında",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tadı berbattı",
    "bayıldım",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yavaş ve ilgisiz",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tam kıvamında",
    "tadı berbattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tadı berbattı",
    "çok rahatsız ediciydi",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "masamız çok kirliydi",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "Yemek geç geldi ve sıcak değildi.",
    "kesinlikle tekrar gelirim",
    "ailece çok sevdik",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "harikaydı",
    "bayıldım",
    "bayıldım",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok lezzetli",
    "çok rahatsız ediciydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yemek geç geldi",
    "Yemek geç geldi ve sıcak değildi.",
    "çok vasattı",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "bayıldım",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "tam kıvamında",
    "çok lezzetli",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "kesinlikle tekrar gelirim",
    "tam kıvamında",
    "çok rahatsız ediciydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "kesinlikle tekrar gelirim",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "temiz ve hızlıydı",
    "harikaydı",
    "Yemek geç geldi ve sıcak değildi.",
    "temiz ve hızlıydı",
    "masamız çok kirliydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "harikaydı",
    "harikaydı",
    "fiyatlar gereksiz pahalı",
    "Yemek geç geldi ve sıcak değildi.",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "bayıldım",
    "bayıldım",
    "çok vasattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "harikaydı",
    "masamız çok kirliydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yemek geç geldi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "bayıldım",
    "ailece çok sevdik",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "Yemek geç geldi ve sıcak değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok rahatsız ediciydi",
    "fiyatlar gereksiz pahalı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "kesinlikle tekrar gelirim",
    "tam kıvamında",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok rahatsız ediciydi",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "bayıldım",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok lezzetli",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "tam kıvamında",
    "çok rahatsız ediciydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok rahatsız ediciydi",
    "çok lezzetli",
    "çok rahatsız ediciydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "çok lezzetli",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yemek geç geldi",
    "yemek geç geldi",
    "ailece çok sevdik",
    "hiç hoşuma gitmedi",
    "çok rahatsız ediciydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "kesinlikle tekrar gelirim",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemek geç geldi ve sıcak değildi.",
    "ailece çok sevdik",
    "çok lezzetli",
    "çok vasattı",
    "ailece çok sevdik",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "hiç hoşuma gitmedi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "kesinlikle tekrar gelirim",
    "çok rahatsız ediciydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "hiç hoşuma gitmedi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "fiyatlar gereksiz pahalı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "tadı berbattı",
    "harikaydı",
    "ailece çok sevdik",
    "tam kıvamında",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "bayıldım",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "ailece çok sevdik",
    "yemek geç geldi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yavaş ve ilgisiz",
    "Yemek geç geldi ve sıcak değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok vasattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok rahatsız ediciydi",
    "fiyatlar gereksiz pahalı",
    "bayıldım",
    "fiyatlar gereksiz pahalı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yavaş ve ilgisiz",
    "çok rahatsız ediciydi",
    "temiz ve hızlıydı",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yavaş ve ilgisiz",
    "temiz ve hızlıydı",
    "kesinlikle tekrar gelirim",
    "tadı berbattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tadı berbattı",
    "tadı berbattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "temiz ve hızlıydı",
    "harikaydı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "çok vasattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "kesinlikle tekrar gelirim",
    "bayıldım",
    "güler yüzlü hizmet",
    "fiyatlar gereksiz pahalı",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "çok vasattı",
    "ailece çok sevdik",
    "tam kıvamında",
    "güler yüzlü hizmet",
    "çok vasattı",
    "tam kıvamında",
    "bayıldım",
    "kesinlikle tekrar gelirim",
    "çok lezzetli",
    "harikaydı",
    "hiç hoşuma gitmedi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemek geç geldi ve sıcak değildi.",
    "kesinlikle tekrar gelirim",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tadı berbattı",
    "tam kıvamında",
    "çok lezzetli",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "hiç hoşuma gitmedi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok vasattı",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "bayıldım",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok vasattı",
    "kesinlikle tekrar gelirim",
    "ailece çok sevdik",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok lezzetli",
    "fiyatlar gereksiz pahalı",
    "Yemek geç geldi ve sıcak değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "bayıldım",
    "Yemek geç geldi ve sıcak değildi.",
    "yemek geç geldi",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "masamız çok kirliydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yemek geç geldi",
    "Yemek geç geldi ve sıcak değildi.",
    "masamız çok kirliydi",
    "tam kıvamında",
    "bayıldım",
    "harikaydı",
    "çok rahatsız ediciydi",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "masamız çok kirliydi",
    "çok lezzetli",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "hiç hoşuma gitmedi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "harikaydı",
    "fiyatlar gereksiz pahalı",
    "harikaydı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "kesinlikle tekrar gelirim",
    "kesinlikle tekrar gelirim",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "çok lezzetli",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "çok rahatsız ediciydi",
    "çok lezzetli",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "fiyatlar gereksiz pahalı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "harikaydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "temiz ve hızlıydı",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "tadı berbattı",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "fiyatlar gereksiz pahalı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "temiz ve hızlıydı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "masamız çok kirliydi",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "bayıldım",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok lezzetli",
    "harikaydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "harikaydı",
    "çok rahatsız ediciydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yemek geç geldi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "hiç hoşuma gitmedi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yemek geç geldi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "harikaydı",
    "çok lezzetli",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "güler yüzlü hizmet",
    "Yemek geç geldi ve sıcak değildi.",
    "çok lezzetli",
    "yavaş ve ilgisiz",
    "çok lezzetli",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "bayıldım",
    "masamız çok kirliydi",
    "kesinlikle tekrar gelirim",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "tadı berbattı",
    "Yemek geç geldi ve sıcak değildi.",
    "masamız çok kirliydi",
    "yemek geç geldi",
    "yavaş ve ilgisiz",
    "hiç hoşuma gitmedi",
    "tam kıvamında",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok vasattı",
    "kesinlikle tekrar gelirim",
    "yavaş ve ilgisiz",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yemek geç geldi",
    "tadı berbattı",
    "bayıldım",
    "tam kıvamında",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok lezzetli",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "masamız çok kirliydi",
    "tadı berbattı",
    "kesinlikle tekrar gelirim",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "kesinlikle tekrar gelirim",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yavaş ve ilgisiz",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok rahatsız ediciydi",
    "tam kıvamında",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "tam kıvamında",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "hiç hoşuma gitmedi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "güler yüzlü hizmet",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "harikaydı",
    "güler yüzlü hizmet",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yemek geç geldi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "bayıldım",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "bayıldım",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "çok rahatsız ediciydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yavaş ve ilgisiz",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "ailece çok sevdik",
    "tadı berbattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok vasattı",
    "temiz ve hızlıydı",
    "kesinlikle tekrar gelirim",
    "güler yüzlü hizmet",
    "yemek geç geldi",
    "çok lezzetli",
    "yavaş ve ilgisiz",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "bayıldım",
    "çok lezzetli",
    "Yemek geç geldi ve sıcak değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yemek geç geldi",
    "kesinlikle tekrar gelirim",
    "yemek geç geldi",
    "yavaş ve ilgisiz",
    "fiyatlar gereksiz pahalı",
    "temiz ve hızlıydı",
    "yemek geç geldi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yemek geç geldi",
    "güler yüzlü hizmet",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yemek geç geldi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok rahatsız ediciydi",
    "çok vasattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "harikaydı",
    "fiyatlar gereksiz pahalı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "bayıldım",
    "güler yüzlü hizmet",
    "Yemek geç geldi ve sıcak değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "ailece çok sevdik",
    "temiz ve hızlıydı",
    "bayıldım",
    "tam kıvamında",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tam kıvamında",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok lezzetli",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "güler yüzlü hizmet",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "harikaydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yemek geç geldi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "kesinlikle tekrar gelirim",
    "çok lezzetli",
    "temiz ve hızlıydı",
    "bayıldım",
    "masamız çok kirliydi",
    "bayıldım",
    "kesinlikle tekrar gelirim",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "temiz ve hızlıydı",
    "kesinlikle tekrar gelirim",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "çok vasattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "masamız çok kirliydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "hiç hoşuma gitmedi",
    "çok vasattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "masamız çok kirliydi",
    "masamız çok kirliydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "hiç hoşuma gitmedi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "güler yüzlü hizmet",
    "yemek geç geldi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "ailece çok sevdik",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "harikaydı",
    "bayıldım",
    "kesinlikle tekrar gelirim",
    "ailece çok sevdik",
    "çok vasattı",
    "yavaş ve ilgisiz",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "harikaydı",
    "Yemek geç geldi ve sıcak değildi.",
    "yavaş ve ilgisiz",
    "bayıldım",
    "tam kıvamında",
    "çok vasattı",
    "fiyatlar gereksiz pahalı",
    "çok lezzetli",
    "güler yüzlü hizmet",
    "tam kıvamında",
    "temiz ve hızlıydı",
    "çok lezzetli",
    "fiyatlar gereksiz pahalı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "güler yüzlü hizmet",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "güler yüzlü hizmet",
    "masamız çok kirliydi",
    "tadı berbattı",
    "tam kıvamında",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "tam kıvamında",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "bayıldım",
    "çok rahatsız ediciydi",
    "çok rahatsız ediciydi",
    "yemek geç geldi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "bayıldım",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "hiç hoşuma gitmedi",
    "çok rahatsız ediciydi",
    "temiz ve hızlıydı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "tam kıvamında",
    "çok rahatsız ediciydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "hiç hoşuma gitmedi",
    "güler yüzlü hizmet",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tam kıvamında",
    "çok lezzetli",
    "kesinlikle tekrar gelirim",
    "temiz ve hızlıydı",
    "güler yüzlü hizmet",
    "çok vasattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "bayıldım",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok vasattı",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok lezzetli",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "tam kıvamında",
    "Yemek geç geldi ve sıcak değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tadı berbattı",
    "fiyatlar gereksiz pahalı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "masamız çok kirliydi",
    "yemek geç geldi",
    "tam kıvamında",
    "çok lezzetli",
    "bayıldım",
    "yemek geç geldi",
    "bayıldım",
    "yavaş ve ilgisiz",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "masamız çok kirliydi",
    "çok rahatsız ediciydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "güler yüzlü hizmet",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "harikaydı",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yemek geç geldi",
    "tadı berbattı",
    "hiç hoşuma gitmedi",
    "Yemek geç geldi ve sıcak değildi.",
    "masamız çok kirliydi",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "güler yüzlü hizmet",
    "çok vasattı",
    "hiç hoşuma gitmedi",
    "çok vasattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok rahatsız ediciydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok vasattı",
    "fiyatlar gereksiz pahalı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "yemek geç geldi",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "ailece çok sevdik",
    "yemek geç geldi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "güler yüzlü hizmet",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "güler yüzlü hizmet",
    "hiç hoşuma gitmedi",
    "çok rahatsız ediciydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "temiz ve hızlıydı",
    "hiç hoşuma gitmedi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok lezzetli",
    "güler yüzlü hizmet",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "tadı berbattı",
    "harikaydı",
    "çok lezzetli",
    "harikaydı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yavaş ve ilgisiz",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tam kıvamında",
    "güler yüzlü hizmet",
    "tam kıvamında",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "ailece çok sevdik",
    "çok lezzetli",
    "ailece çok sevdik",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tadı berbattı",
    "çok rahatsız ediciydi",
    "temiz ve hızlıydı",
    "güler yüzlü hizmet",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tadı berbattı",
    "tadı berbattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "tadı berbattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "hiç hoşuma gitmedi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yavaş ve ilgisiz",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok lezzetli",
    "kesinlikle tekrar gelirim",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok vasattı",
    "ailece çok sevdik",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "temiz ve hızlıydı",
    "yavaş ve ilgisiz",
    "çok rahatsız ediciydi",
    "masamız çok kirliydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "ailece çok sevdik",
    "hiç hoşuma gitmedi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "bayıldım",
    "yavaş ve ilgisiz",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "fiyatlar gereksiz pahalı",
    "fiyatlar gereksiz pahalı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "bayıldım",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "güler yüzlü hizmet",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tadı berbattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "hiç hoşuma gitmedi",
    "hiç hoşuma gitmedi",
    "temiz ve hızlıydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yavaş ve ilgisiz",
    "hiç hoşuma gitmedi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "tadı berbattı",
    "kesinlikle tekrar gelirim",
    "masamız çok kirliydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "fiyatlar gereksiz pahalı",
    "yavaş ve ilgisiz",
    "harikaydı",
    "çok vasattı",
    "güler yüzlü hizmet",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yemek geç geldi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok vasattı",
    "tadı berbattı",
    "hiç hoşuma gitmedi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "ailece çok sevdik",
    "tadı berbattı",
    "bayıldım",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "çok vasattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "güler yüzlü hizmet",
    "çok vasattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok vasattı",
    "bayıldım",
    "ailece çok sevdik",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "yavaş ve ilgisiz",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "tam kıvamında",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yemek geç geldi",
    "ailece çok sevdik",
    "temiz ve hızlıydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "güler yüzlü hizmet",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yavaş ve ilgisiz",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "ailece çok sevdik",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "kesinlikle tekrar gelirim",
    "hiç hoşuma gitmedi",
    "hiç hoşuma gitmedi",
    "çok rahatsız ediciydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yavaş ve ilgisiz",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok rahatsız ediciydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tam kıvamında",
    "bayıldım",
    "çok vasattı",
    "harikaydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok lezzetli",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "temiz ve hızlıydı",
    "yemek geç geldi",
    "tam kıvamında",
    "çok rahatsız ediciydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yavaş ve ilgisiz",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok rahatsız ediciydi",
    "masamız çok kirliydi",
    "yavaş ve ilgisiz",
    "tam kıvamında",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tam kıvamında",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "harikaydı",
    "kesinlikle tekrar gelirim",
    "fiyatlar gereksiz pahalı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "yemek geç geldi",
    "harikaydı",
    "tadı berbattı",
    "çok rahatsız ediciydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "bayıldım",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok lezzetli",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "bayıldım",
    "çok lezzetli",
    "çok lezzetli",
    "masamız çok kirliydi",
    "yemek geç geldi",
    "kesinlikle tekrar gelirim",
    "Yemek geç geldi ve sıcak değildi.",
    "temiz ve hızlıydı",
    "fiyatlar gereksiz pahalı",
    "bayıldım",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "harikaydı",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "harikaydı",
    "çok vasattı",
    "çok vasattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "bayıldım",
    "ailece çok sevdik",
    "çok rahatsız ediciydi",
    "yavaş ve ilgisiz",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok rahatsız ediciydi",
    "bayıldım",
    "yavaş ve ilgisiz",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "ailece çok sevdik",
    "çok lezzetli",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "ailece çok sevdik",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "temiz ve hızlıydı",
    "çok rahatsız ediciydi",
    "tam kıvamında",
    "temiz ve hızlıydı",
    "ailece çok sevdik",
    "çok vasattı",
    "tam kıvamında",
    "çok rahatsız ediciydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "hiç hoşuma gitmedi",
    "ailece çok sevdik",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "ailece çok sevdik",
    "yavaş ve ilgisiz",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "hiç hoşuma gitmedi",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "güler yüzlü hizmet",
    "kesinlikle tekrar gelirim",
    "yemek geç geldi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "bayıldım",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "fiyatlar gereksiz pahalı",
    "temiz ve hızlıydı",
    "çok vasattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "masamız çok kirliydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yemek geç geldi",
    "güler yüzlü hizmet",
    "bayıldım",
    "yemek geç geldi",
    "harikaydı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "temiz ve hızlıydı",
    "Yemek geç geldi ve sıcak değildi.",
    "çok rahatsız ediciydi",
    "çok lezzetli",
    "hiç hoşuma gitmedi",
    "Yemek geç geldi ve sıcak değildi.",
    "ailece çok sevdik",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "ailece çok sevdik",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "fiyatlar gereksiz pahalı",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok lezzetli",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "güler yüzlü hizmet",
    "fiyatlar gereksiz pahalı",
    "güler yüzlü hizmet",
    "masamız çok kirliydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "temiz ve hızlıydı",
    "harikaydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yemek geç geldi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "masamız çok kirliydi",
    "hiç hoşuma gitmedi",
    "çok lezzetli",
    "çok vasattı",
    "yavaş ve ilgisiz",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "çok rahatsız ediciydi",
    "tadı berbattı",
    "çok vasattı",
    "Yemek geç geldi ve sıcak değildi.",
    "çok rahatsız ediciydi",
    "çok vasattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "temiz ve hızlıydı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "kesinlikle tekrar gelirim",
    "yavaş ve ilgisiz",
    "ailece çok sevdik",
    "çok rahatsız ediciydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tadı berbattı",
    "fiyatlar gereksiz pahalı",
    "çok lezzetli",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tam kıvamında",
    "çok vasattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok rahatsız ediciydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok vasattı",
    "yemek geç geldi",
    "yavaş ve ilgisiz",
    "güler yüzlü hizmet",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "güler yüzlü hizmet",
    "Yemek geç geldi ve sıcak değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "kesinlikle tekrar gelirim",
    "çok vasattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yavaş ve ilgisiz",
    "güler yüzlü hizmet",
    "kesinlikle tekrar gelirim",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tadı berbattı",
    "tadı berbattı",
    "temiz ve hızlıydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "hiç hoşuma gitmedi",
    "tadı berbattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "güler yüzlü hizmet",
    "tam kıvamında",
    "fiyatlar gereksiz pahalı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "fiyatlar gereksiz pahalı",
    "bayıldım",
    "hiç hoşuma gitmedi",
    "çok rahatsız ediciydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "temiz ve hızlıydı",
    "yavaş ve ilgisiz",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Yemek geç geldi ve sıcak değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok vasattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tadı berbattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "fiyatlar gereksiz pahalı",
    "Yemek geç geldi ve sıcak değildi.",
    "tam kıvamında",
    "masamız çok kirliydi",
    "masamız çok kirliydi",
    "yavaş ve ilgisiz",
    "çok vasattı",
    "fiyatlar gereksiz pahalı",
    "fiyatlar gereksiz pahalı",
    "bayıldım",
    "ailece çok sevdik",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "bayıldım",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok rahatsız ediciydi",
    "masamız çok kirliydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "hiç hoşuma gitmedi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "güler yüzlü hizmet",
    "çok lezzetli",
    "çok rahatsız ediciydi",
    "kesinlikle tekrar gelirim",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "kesinlikle tekrar gelirim",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "bayıldım",
    "harikaydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok rahatsız ediciydi",
    "çok vasattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "çok vasattı",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "masamız çok kirliydi",
    "bayıldım",
    "fiyatlar gereksiz pahalı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "masamız çok kirliydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tam kıvamında",
    "fiyatlar gereksiz pahalı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "harikaydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "kesinlikle tekrar gelirim",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "hiç hoşuma gitmedi",
    "yavaş ve ilgisiz",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Yemek geç geldi ve sıcak değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "yavaş ve ilgisiz",
    "bayıldım",
    "yemek geç geldi",
    "çok rahatsız ediciydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "masamız çok kirliydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "ailece çok sevdik",
    "harikaydı",
    "kesinlikle tekrar gelirim",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yavaş ve ilgisiz",
    "fiyatlar gereksiz pahalı",
    "hiç hoşuma gitmedi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok rahatsız ediciydi",
    "fiyatlar gereksiz pahalı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "bayıldım",
    "yemek geç geldi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yemek geç geldi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemek geç geldi ve sıcak değildi.",
    "bayıldım",
    "Yemek geç geldi ve sıcak değildi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "temiz ve hızlıydı",
    "masamız çok kirliydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "kesinlikle tekrar gelirim",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "harikaydı",
    "yemek geç geldi",
    "temiz ve hızlıydı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok vasattı",
    "yemek geç geldi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tadı berbattı",
    "ailece çok sevdik",
    "yemek geç geldi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "temiz ve hızlıydı",
    "kesinlikle tekrar gelirim",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "temiz ve hızlıydı",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "fiyatlar gereksiz pahalı",
    "fiyatlar gereksiz pahalı",
    "fiyatlar gereksiz pahalı",
    "bayıldım",
    "temiz ve hızlıydı",
    "çok vasattı",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "ailece çok sevdik",
    "çok rahatsız ediciydi",
    "hiç hoşuma gitmedi",
    "ailece çok sevdik",
    "çok rahatsız ediciydi",
    "çok vasattı",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "güler yüzlü hizmet",
    "kesinlikle tekrar gelirim",
    "yavaş ve ilgisiz",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "temiz ve hızlıydı",
    "bayıldım",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "bayıldım",
    "yavaş ve ilgisiz",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "güler yüzlü hizmet",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "temiz ve hızlıydı",
    "Yemek geç geldi ve sıcak değildi.",
    "hiç hoşuma gitmedi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "güler yüzlü hizmet",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yavaş ve ilgisiz",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tam kıvamında",
    "bayıldım",
    "Yemek geç geldi ve sıcak değildi.",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "bayıldım",
    "ailece çok sevdik",
    "güler yüzlü hizmet",
    "fiyatlar gereksiz pahalı",
    "tadı berbattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "masamız çok kirliydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "ailece çok sevdik",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "ailece çok sevdik",
    "masamız çok kirliydi",
    "yemek geç geldi",
    "masamız çok kirliydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "hiç hoşuma gitmedi",
    "harikaydı",
    "masamız çok kirliydi",
    "Yemek geç geldi ve sıcak değildi.",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "çok lezzetli",
    "masamız çok kirliydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "harikaydı",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "temiz ve hızlıydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "hiç hoşuma gitmedi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "fiyatlar gereksiz pahalı",
    "tadı berbattı",
    "kesinlikle tekrar gelirim",
    "çok rahatsız ediciydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tam kıvamında",
    "fiyatlar gereksiz pahalı",
    "yemek geç geldi",
    "Yemek geç geldi ve sıcak değildi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "temiz ve hızlıydı",
    "ailece çok sevdik",
    "çok lezzetli",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "masamız çok kirliydi",
    "Yemek geç geldi ve sıcak değildi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yemek geç geldi",
    "bayıldım",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yemek geç geldi",
    "çok vasattı",
    "temiz ve hızlıydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yavaş ve ilgisiz",
    "çok rahatsız ediciydi",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "hiç hoşuma gitmedi",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "çok rahatsız ediciydi",
    "fiyatlar gereksiz pahalı",
    "fiyatlar gereksiz pahalı",
    "masamız çok kirliydi",
    "harikaydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "masamız çok kirliydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "güler yüzlü hizmet",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok vasattı",
    "kesinlikle tekrar gelirim",
    "masamız çok kirliydi",
    "tam kıvamında",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemek geç geldi ve sıcak değildi.",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "yavaş ve ilgisiz",
    "çok rahatsız ediciydi",
    "yemek geç geldi",
    "çok lezzetli",
    "hiç hoşuma gitmedi",
    "yavaş ve ilgisiz",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "masamız çok kirliydi",
    "yemek geç geldi",
    "ailece çok sevdik",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok rahatsız ediciydi",
    "çok lezzetli",
    "masamız çok kirliydi",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yavaş ve ilgisiz",
    "çok lezzetli",
    "bayıldım",
    "harikaydı",
    "güler yüzlü hizmet",
    "harikaydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yemek geç geldi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "çok vasattı",
    "harikaydı",
    "temiz ve hızlıydı",
    "yemek geç geldi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "bayıldım",
    "güler yüzlü hizmet",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "çok lezzetli",
    "bayıldım",
    "harikaydı",
    "masamız çok kirliydi",
    "Yemek geç geldi ve sıcak değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "temiz ve hızlıydı",
    "ailece çok sevdik",
    "temiz ve hızlıydı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "temiz ve hızlıydı",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "harikaydı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok rahatsız ediciydi",
    "çok vasattı",
    "güler yüzlü hizmet",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "hiç hoşuma gitmedi",
    "çok vasattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemek geç geldi ve sıcak değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "masamız çok kirliydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok vasattı",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "masamız çok kirliydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok rahatsız ediciydi",
    "bayıldım",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "yemek geç geldi",
    "Yemek geç geldi ve sıcak değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "harikaydı",
    "fiyatlar gereksiz pahalı",
    "ailece çok sevdik",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "bayıldım",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "bayıldım",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "masamız çok kirliydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok lezzetli",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "temiz ve hızlıydı",
    "temiz ve hızlıydı",
    "çok vasattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yemek geç geldi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "fiyatlar gereksiz pahalı",
    "hiç hoşuma gitmedi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok lezzetli",
    "yemek geç geldi",
    "hiç hoşuma gitmedi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "güler yüzlü hizmet",
    "fiyatlar gereksiz pahalı",
    "tam kıvamında",
    "masamız çok kirliydi",
    "harikaydı",
    "kesinlikle tekrar gelirim",
    "hiç hoşuma gitmedi",
    "hiç hoşuma gitmedi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "kesinlikle tekrar gelirim",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yemek geç geldi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "harikaydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "güler yüzlü hizmet",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "tam kıvamında",
    "fiyatlar gereksiz pahalı",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "tadı berbattı",
    "tam kıvamında",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "hiç hoşuma gitmedi",
    "yavaş ve ilgisiz",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "masamız çok kirliydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tadı berbattı",
    "hiç hoşuma gitmedi",
    "yemek geç geldi",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "çok rahatsız ediciydi",
    "tadı berbattı",
    "güler yüzlü hizmet",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "hiç hoşuma gitmedi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yavaş ve ilgisiz",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yavaş ve ilgisiz",
    "çok rahatsız ediciydi",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "masamız çok kirliydi",
    "Yemek geç geldi ve sıcak değildi.",
    "masamız çok kirliydi",
    "çok rahatsız ediciydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "harikaydı",
    "tam kıvamında",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok lezzetli",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "Yemek geç geldi ve sıcak değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "masamız çok kirliydi",
    "hiç hoşuma gitmedi",
    "tam kıvamında",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "fiyatlar gereksiz pahalı",
    "tam kıvamında",
    "kesinlikle tekrar gelirim",
    "güler yüzlü hizmet",
    "güler yüzlü hizmet",
    "tadı berbattı",
    "fiyatlar gereksiz pahalı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yemek geç geldi",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "fiyatlar gereksiz pahalı",
    "Yemek geç geldi ve sıcak değildi.",
    "ailece çok sevdik",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tadı berbattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok vasattı",
    "temiz ve hızlıydı",
    "çok lezzetli",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok lezzetli",
    "yemek geç geldi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok lezzetli",
    "yavaş ve ilgisiz",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "hiç hoşuma gitmedi",
    "tam kıvamında",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok vasattı",
    "yemek geç geldi",
    "güler yüzlü hizmet",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "temiz ve hızlıydı",
    "harikaydı",
    "harikaydı",
    "tam kıvamında",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "fiyatlar gereksiz pahalı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok rahatsız ediciydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "bayıldım",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "masamız çok kirliydi",
    "tadı berbattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok rahatsız ediciydi",
    "tadı berbattı",
    "tam kıvamında",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok rahatsız ediciydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok lezzetli",
    "hiç hoşuma gitmedi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok rahatsız ediciydi",
    "ailece çok sevdik",
    "fiyatlar gereksiz pahalı",
    "fiyatlar gereksiz pahalı",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "bayıldım",
    "masamız çok kirliydi",
    "yemek geç geldi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "bayıldım",
    "yavaş ve ilgisiz",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "güler yüzlü hizmet",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "bayıldım",
    "çok rahatsız ediciydi",
    "ailece çok sevdik",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok vasattı",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "ailece çok sevdik",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "güler yüzlü hizmet",
    "yemek geç geldi",
    "güler yüzlü hizmet",
    "yemek geç geldi",
    "tam kıvamında",
    "temiz ve hızlıydı",
    "harikaydı",
    "tadı berbattı",
    "kesinlikle tekrar gelirim",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "hiç hoşuma gitmedi",
    "bayıldım",
    "ailece çok sevdik",
    "masamız çok kirliydi",
    "harikaydı",
    "kesinlikle tekrar gelirim",
    "Yemek geç geldi ve sıcak değildi.",
    "tam kıvamında",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok rahatsız ediciydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "güler yüzlü hizmet",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "kesinlikle tekrar gelirim",
    "Yemek geç geldi ve sıcak değildi.",
    "temiz ve hızlıydı",
    "çok rahatsız ediciydi",
    "çok lezzetli",
    "masamız çok kirliydi",
    "çok lezzetli",
    "ailece çok sevdik",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "harikaydı",
    "Yemek geç geldi ve sıcak değildi.",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "çok vasattı",
    "güler yüzlü hizmet",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok lezzetli",
    "fiyatlar gereksiz pahalı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "harikaydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok rahatsız ediciydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yemek geç geldi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "bayıldım",
    "masamız çok kirliydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tam kıvamında",
    "yavaş ve ilgisiz",
    "çok vasattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok lezzetli",
    "harikaydı",
    "hiç hoşuma gitmedi",
    "bayıldım",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemek geç geldi ve sıcak değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "hiç hoşuma gitmedi",
    "temiz ve hızlıydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "bayıldım",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "çok lezzetli",
    "tam kıvamında",
    "fiyatlar gereksiz pahalı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok rahatsız ediciydi",
    "tam kıvamında",
    "temiz ve hızlıydı",
    "harikaydı",
    "tadı berbattı",
    "tadı berbattı",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "temiz ve hızlıydı",
    "çok rahatsız ediciydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "tadı berbattı",
    "tadı berbattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok lezzetli",
    "Yemek geç geldi ve sıcak değildi.",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "tam kıvamında",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "hiç hoşuma gitmedi",
    "kesinlikle tekrar gelirim",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tadı berbattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok lezzetli",
    "temiz ve hızlıydı",
    "tadı berbattı",
    "çok vasattı",
    "çok vasattı",
    "tam kıvamında",
    "çok vasattı",
    "harikaydı",
    "tam kıvamında",
    "yavaş ve ilgisiz",
    "bayıldım",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "kesinlikle tekrar gelirim",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yemek geç geldi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "hiç hoşuma gitmedi",
    "yavaş ve ilgisiz",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "tadı berbattı",
    "tam kıvamında",
    "kesinlikle tekrar gelirim",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok vasattı",
    "masamız çok kirliydi",
    "çok rahatsız ediciydi",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "kesinlikle tekrar gelirim",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "tam kıvamında",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok rahatsız ediciydi",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "hiç hoşuma gitmedi",
    "ailece çok sevdik",
    "masamız çok kirliydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "masamız çok kirliydi",
    "bayıldım",
    "çok rahatsız ediciydi",
    "hiç hoşuma gitmedi",
    "çok rahatsız ediciydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "fiyatlar gereksiz pahalı",
    "güler yüzlü hizmet",
    "fiyatlar gereksiz pahalı",
    "masamız çok kirliydi",
    "yemek geç geldi",
    "tam kıvamında",
    "fiyatlar gereksiz pahalı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok vasattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yavaş ve ilgisiz",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "tadı berbattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "bayıldım",
    "çok vasattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok lezzetli",
    "masamız çok kirliydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "hiç hoşuma gitmedi",
    "güler yüzlü hizmet",
    "güler yüzlü hizmet",
    "tam kıvamında",
    "fiyatlar gereksiz pahalı",
    "Yemek geç geldi ve sıcak değildi.",
    "tadı berbattı",
    "harikaydı",
    "tam kıvamında",
    "ailece çok sevdik",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok lezzetli",
    "fiyatlar gereksiz pahalı",
    "çok lezzetli",
    "güler yüzlü hizmet",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "kesinlikle tekrar gelirim",
    "kesinlikle tekrar gelirim",
    "kesinlikle tekrar gelirim",
    "yemek geç geldi",
    "ailece çok sevdik",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "bayıldım",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "masamız çok kirliydi",
    "Yemek geç geldi ve sıcak değildi.",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "harikaydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "güler yüzlü hizmet",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok vasattı",
    "yemek geç geldi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok vasattı",
    "harikaydı",
    "hiç hoşuma gitmedi",
    "harikaydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "masamız çok kirliydi",
    "tadı berbattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "bayıldım",
    "tadı berbattı",
    "yemek geç geldi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "hiç hoşuma gitmedi",
    "tadı berbattı",
    "fiyatlar gereksiz pahalı",
    "tadı berbattı",
    "bayıldım",
    "yemek geç geldi",
    "çok rahatsız ediciydi",
    "çok rahatsız ediciydi",
    "hiç hoşuma gitmedi",
    "çok vasattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok vasattı",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "bayıldım",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "çok vasattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tam kıvamında",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "temiz ve hızlıydı",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "masamız çok kirliydi",
    "çok lezzetli",
    "tam kıvamında",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "harikaydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yemek geç geldi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "temiz ve hızlıydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemek geç geldi ve sıcak değildi.",
    "yemek geç geldi",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "yavaş ve ilgisiz",
    "çok lezzetli",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tadı berbattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok rahatsız ediciydi",
    "tadı berbattı",
    "tadı berbattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "hiç hoşuma gitmedi",
    "yemek geç geldi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "fiyatlar gereksiz pahalı",
    "masamız çok kirliydi",
    "kesinlikle tekrar gelirim",
    "çok vasattı",
    "çok rahatsız ediciydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "temiz ve hızlıydı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "kesinlikle tekrar gelirim",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "temiz ve hızlıydı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "tam kıvamında",
    "tadı berbattı",
    "yemek geç geldi",
    "yavaş ve ilgisiz",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "ailece çok sevdik",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "bayıldım",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yavaş ve ilgisiz",
    "çok lezzetli",
    "çok rahatsız ediciydi",
    "tadı berbattı",
    "Yemek geç geldi ve sıcak değildi.",
    "tadı berbattı",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "ailece çok sevdik",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yemek geç geldi",
    "güler yüzlü hizmet",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "masamız çok kirliydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok vasattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "masamız çok kirliydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "harikaydı",
    "çok lezzetli",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "yemek geç geldi",
    "çok lezzetli",
    "ailece çok sevdik",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "kesinlikle tekrar gelirim",
    "tam kıvamında",
    "temiz ve hızlıydı",
    "fiyatlar gereksiz pahalı",
    "Yemek geç geldi ve sıcak değildi.",
    "hiç hoşuma gitmedi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "ailece çok sevdik",
    "çok rahatsız ediciydi",
    "kesinlikle tekrar gelirim",
    "masamız çok kirliydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "güler yüzlü hizmet",
    "fiyatlar gereksiz pahalı",
    "çok lezzetli",
    "çok lezzetli",
    "çok lezzetli",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok lezzetli",
    "bayıldım",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yavaş ve ilgisiz",
    "hiç hoşuma gitmedi",
    "temiz ve hızlıydı",
    "kesinlikle tekrar gelirim",
    "yemek geç geldi",
    "harikaydı",
    "temiz ve hızlıydı",
    "temiz ve hızlıydı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "ailece çok sevdik",
    "hiç hoşuma gitmedi",
    "tadı berbattı",
    "güler yüzlü hizmet",
    "kesinlikle tekrar gelirim",
    "masamız çok kirliydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "ailece çok sevdik",
    "yemek geç geldi",
    "kesinlikle tekrar gelirim",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "kesinlikle tekrar gelirim",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "güler yüzlü hizmet",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "kesinlikle tekrar gelirim",
    "harikaydı",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "hiç hoşuma gitmedi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yemek geç geldi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "harikaydı",
    "çok vasattı",
    "bayıldım",
    "güler yüzlü hizmet",
    "yavaş ve ilgisiz",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "bayıldım",
    "yemek geç geldi",
    "yavaş ve ilgisiz",
    "masamız çok kirliydi",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "yavaş ve ilgisiz",
    "bayıldım",
    "masamız çok kirliydi",
    "hiç hoşuma gitmedi",
    "temiz ve hızlıydı",
    "temiz ve hızlıydı",
    "yemek geç geldi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok lezzetli",
    "ailece çok sevdik",
    "Yemek geç geldi ve sıcak değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "harikaydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "fiyatlar gereksiz pahalı",
    "çok vasattı",
    "fiyatlar gereksiz pahalı",
    "tadı berbattı",
    "tadı berbattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "masamız çok kirliydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "masamız çok kirliydi",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yavaş ve ilgisiz",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "bayıldım",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tadı berbattı",
    "tadı berbattı",
    "bayıldım",
    "tam kıvamında",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "tam kıvamında",
    "yavaş ve ilgisiz",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yemek geç geldi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "ailece çok sevdik",
    "masamız çok kirliydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok lezzetli",
    "ailece çok sevdik",
    "bayıldım",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok rahatsız ediciydi",
    "çok lezzetli",
    "temiz ve hızlıydı",
    "Yemek geç geldi ve sıcak değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "masamız çok kirliydi",
    "harikaydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "Yemek geç geldi ve sıcak değildi.",
    "yavaş ve ilgisiz",
    "fiyatlar gereksiz pahalı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tam kıvamında",
    "ailece çok sevdik",
    "hiç hoşuma gitmedi",
    "fiyatlar gereksiz pahalı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "masamız çok kirliydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "bayıldım",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "hiç hoşuma gitmedi",
    "bayıldım",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yavaş ve ilgisiz",
    "temiz ve hızlıydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok rahatsız ediciydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "harikaydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tadı berbattı",
    "çok lezzetli",
    "Yemek geç geldi ve sıcak değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "ailece çok sevdik",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "temiz ve hızlıydı",
    "çok lezzetli",
    "çok vasattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "kesinlikle tekrar gelirim",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "güler yüzlü hizmet",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "yemek geç geldi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "hiç hoşuma gitmedi",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "bayıldım",
    "tadı berbattı",
    "güler yüzlü hizmet",
    "yemek geç geldi",
    "çok rahatsız ediciydi",
    "ailece çok sevdik",
    "tadı berbattı",
    "çok rahatsız ediciydi",
    "çok vasattı",
    "Yemek geç geldi ve sıcak değildi.",
    "çok vasattı",
    "hiç hoşuma gitmedi",
    "bayıldım",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "temiz ve hızlıydı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "hiç hoşuma gitmedi",
    "bayıldım",
    "fiyatlar gereksiz pahalı",
    "çok rahatsız ediciydi",
    "tam kıvamında",
    "temiz ve hızlıydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "tadı berbattı",
    "yemek geç geldi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yavaş ve ilgisiz",
    "masamız çok kirliydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tadı berbattı",
    "masamız çok kirliydi",
    "kesinlikle tekrar gelirim",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "temiz ve hızlıydı",
    "bayıldım",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "tam kıvamında",
    "güler yüzlü hizmet",
    "kesinlikle tekrar gelirim",
    "hiç hoşuma gitmedi",
    "çok lezzetli",
    "kesinlikle tekrar gelirim",
    "temiz ve hızlıydı",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yavaş ve ilgisiz",
    "harikaydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok lezzetli",
    "tadı berbattı",
    "güler yüzlü hizmet",
    "ailece çok sevdik",
    "tadı berbattı",
    "temiz ve hızlıydı",
    "ailece çok sevdik",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "temiz ve hızlıydı",
    "çok lezzetli",
    "güler yüzlü hizmet",
    "temiz ve hızlıydı",
    "çok vasattı",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "kesinlikle tekrar gelirim",
    "bayıldım",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok rahatsız ediciydi",
    "çok lezzetli",
    "yemek geç geldi",
    "Yemek geç geldi ve sıcak değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "masamız çok kirliydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "kesinlikle tekrar gelirim",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok vasattı",
    "çok lezzetli",
    "tadı berbattı",
    "harikaydı",
    "ailece çok sevdik",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "bayıldım",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok lezzetli",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "fiyatlar gereksiz pahalı",
    "yavaş ve ilgisiz",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "harikaydı",
    "yavaş ve ilgisiz",
    "harikaydı",
    "masamız çok kirliydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok vasattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok vasattı",
    "hiç hoşuma gitmedi",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "tam kıvamında",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "temiz ve hızlıydı",
    "temiz ve hızlıydı",
    "hiç hoşuma gitmedi",
    "harikaydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok vasattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "hiç hoşuma gitmedi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "harikaydı",
    "ailece çok sevdik",
    "çok vasattı",
    "ailece çok sevdik",
    "harikaydı",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "güler yüzlü hizmet",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "güler yüzlü hizmet",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tam kıvamında",
    "kesinlikle tekrar gelirim",
    "çok rahatsız ediciydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "hiç hoşuma gitmedi",
    "bayıldım",
    "harikaydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "ailece çok sevdik",
    "bayıldım",
    "çok rahatsız ediciydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "ailece çok sevdik",
    "harikaydı",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok lezzetli",
    "çok vasattı",
    "masamız çok kirliydi",
    "güler yüzlü hizmet",
    "çok lezzetli",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yavaş ve ilgisiz",
    "yavaş ve ilgisiz",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Yemek geç geldi ve sıcak değildi.",
    "yavaş ve ilgisiz",
    "kesinlikle tekrar gelirim",
    "fiyatlar gereksiz pahalı",
    "tam kıvamında",
    "güler yüzlü hizmet",
    "çok vasattı",
    "ailece çok sevdik",
    "yemek geç geldi",
    "yemek geç geldi",
    "yavaş ve ilgisiz",
    "hiç hoşuma gitmedi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "temiz ve hızlıydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "hiç hoşuma gitmedi",
    "tadı berbattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "fiyatlar gereksiz pahalı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "kesinlikle tekrar gelirim",
    "fiyatlar gereksiz pahalı",
    "yemek geç geldi",
    "Yemek geç geldi ve sıcak değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok rahatsız ediciydi",
    "çok lezzetli",
    "hiç hoşuma gitmedi",
    "kesinlikle tekrar gelirim",
    "hiç hoşuma gitmedi",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "masamız çok kirliydi",
    "hiç hoşuma gitmedi",
    "çok rahatsız ediciydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "bayıldım",
    "masamız çok kirliydi",
    "çok lezzetli",
    "bayıldım",
    "ailece çok sevdik",
    "çok rahatsız ediciydi",
    "yemek geç geldi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "harikaydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok vasattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "bayıldım",
    "güler yüzlü hizmet",
    "çok rahatsız ediciydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok rahatsız ediciydi",
    "harikaydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yemek geç geldi",
    "hiç hoşuma gitmedi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok vasattı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "harikaydı",
    "kesinlikle tekrar gelirim",
    "masamız çok kirliydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok rahatsız ediciydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "bayıldım",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yavaş ve ilgisiz",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tadı berbattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "kesinlikle tekrar gelirim",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "yavaş ve ilgisiz",
    "tadı berbattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "kesinlikle tekrar gelirim",
    "kesinlikle tekrar gelirim",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "ailece çok sevdik",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "bayıldım",
    "Yemek geç geldi ve sıcak değildi.",
    "ailece çok sevdik",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "harikaydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "tam kıvamında",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "harikaydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "bayıldım",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "masamız çok kirliydi",
    "çok vasattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "kesinlikle tekrar gelirim",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "bayıldım",
    "fiyatlar gereksiz pahalı",
    "harikaydı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yavaş ve ilgisiz",
    "harikaydı",
    "bayıldım",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "fiyatlar gereksiz pahalı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yemek geç geldi",
    "bayıldım",
    "harikaydı",
    "hiç hoşuma gitmedi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "harikaydı",
    "çok rahatsız ediciydi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tadı berbattı",
    "yemek geç geldi",
    "harikaydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok lezzetli",
    "çok rahatsız ediciydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "yavaş ve ilgisiz",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "masamız çok kirliydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "çok lezzetli",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok rahatsız ediciydi",
    "çok rahatsız ediciydi",
    "kesinlikle tekrar gelirim",
    "kesinlikle tekrar gelirim",
    "tam kıvamında",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "çok vasattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "hiç hoşuma gitmedi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yavaş ve ilgisiz",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "masamız çok kirliydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok rahatsız ediciydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "tam kıvamında",
    "tadı berbattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tadı berbattı",
    "masamız çok kirliydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemek geç geldi ve sıcak değildi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tadı berbattı",
    "yavaş ve ilgisiz",
    "masamız çok kirliydi",
    "bayıldım",
    "güler yüzlü hizmet",
    "tadı berbattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "ailece çok sevdik",
    "yemek geç geldi",
    "Yemek geç geldi ve sıcak değildi.",
    "temiz ve hızlıydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok lezzetli",
    "fiyatlar gereksiz pahalı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "temiz ve hızlıydı",
    "temiz ve hızlıydı",
    "tadı berbattı",
    "çok vasattı",
    "tadı berbattı",
    "çok rahatsız ediciydi",
    "çok rahatsız ediciydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "temiz ve hızlıydı",
    "güler yüzlü hizmet",
    "kesinlikle tekrar gelirim",
    "yavaş ve ilgisiz",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemek geç geldi ve sıcak değildi.",
    "tadı berbattı",
    "fiyatlar gereksiz pahalı",
    "çok lezzetli",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "güler yüzlü hizmet",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "harikaydı",
    "çok lezzetli",
    "bayıldım",
    "masamız çok kirliydi",
    "Yemek geç geldi ve sıcak değildi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok vasattı",
    "çok lezzetli",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yavaş ve ilgisiz",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok vasattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yemek geç geldi",
    "fiyatlar gereksiz pahalı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "tadı berbattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "masamız çok kirliydi",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "hiç hoşuma gitmedi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "harikaydı",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "tam kıvamında",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "bayıldım",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tam kıvamında",
    "temiz ve hızlıydı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yavaş ve ilgisiz",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "tam kıvamında",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "yemek geç geldi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok rahatsız ediciydi",
    "tam kıvamında",
    "tam kıvamında",
    "kesinlikle tekrar gelirim",
    "kesinlikle tekrar gelirim",
    "ailece çok sevdik",
    "fiyatlar gereksiz pahalı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "fiyatlar gereksiz pahalı",
    "fiyatlar gereksiz pahalı",
    "güler yüzlü hizmet",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "temiz ve hızlıydı",
    "çok vasattı",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "tam kıvamında",
    "Yemek geç geldi ve sıcak değildi.",
    "ailece çok sevdik",
    "masamız çok kirliydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "güler yüzlü hizmet",
    "masamız çok kirliydi",
    "güler yüzlü hizmet",
    "güler yüzlü hizmet",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "tadı berbattı",
    "ailece çok sevdik",
    "masamız çok kirliydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "tadı berbattı",
    "çok vasattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "fiyatlar gereksiz pahalı",
    "ailece çok sevdik",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok rahatsız ediciydi",
    "çok lezzetli",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "tadı berbattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "hiç hoşuma gitmedi",
    "harikaydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok lezzetli",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "kesinlikle tekrar gelirim",
    "çok vasattı",
    "Yemek geç geldi ve sıcak değildi.",
    "ailece çok sevdik",
    "tam kıvamında",
    "kesinlikle tekrar gelirim",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "masamız çok kirliydi",
    "çok rahatsız ediciydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "masamız çok kirliydi",
    "kesinlikle tekrar gelirim",
    "Yemek geç geldi ve sıcak değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "çok lezzetli",
    "çok rahatsız ediciydi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Yemek geç geldi ve sıcak değildi.",
    "güler yüzlü hizmet",
    "güler yüzlü hizmet",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok rahatsız ediciydi",
    "hiç hoşuma gitmedi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "kesinlikle tekrar gelirim",
    "çok lezzetli",
    "kesinlikle tekrar gelirim",
    "bayıldım",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok lezzetli",
    "harikaydı",
    "ailece çok sevdik",
    "kesinlikle tekrar gelirim",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tadı berbattı",
    "masamız çok kirliydi",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "masamız çok kirliydi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "çok lezzetli",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "ailece çok sevdik",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "temiz ve hızlıydı",
    "çok lezzetli",
    "yavaş ve ilgisiz",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "harikaydı",
    "çok vasattı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "harikaydı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok vasattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "çok rahatsız ediciydi",
    "güler yüzlü hizmet",
    "çok lezzetli",
    "Yemek geç geldi ve sıcak değildi.",
    "harikaydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok rahatsız ediciydi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "ailece çok sevdik",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yemek geç geldi",
    "temiz ve hızlıydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Yemek geç geldi ve sıcak değildi.",
    "kesinlikle tekrar gelirim",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "ailece çok sevdik",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "kesinlikle tekrar gelirim",
    "ailece çok sevdik",
    "tam kıvamında",
    "çok lezzetli",
    "masamız çok kirliydi",
    "tam kıvamında",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "tadı berbattı",
    "güler yüzlü hizmet",
    "Yemek geç geldi ve sıcak değildi.",
    "yemek geç geldi",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "temiz ve hızlıydı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "yemek geç geldi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok rahatsız ediciydi",
    "tam kıvamında",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "çok vasattı",
    "tadı berbattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "fiyatlar gereksiz pahalı",
    "temiz ve hızlıydı",
    "temiz ve hızlıydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "harikaydı",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yavaş ve ilgisiz",
    "harikaydı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemek geç geldi ve sıcak değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "yemek geç geldi",
    "güler yüzlü hizmet",
    "kesinlikle tekrar gelirim",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "temiz ve hızlıydı",
    "yavaş ve ilgisiz",
    "bayıldım",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "kesinlikle tekrar gelirim",
    "tadı berbattı",
    "hiç hoşuma gitmedi",
    "tadı berbattı",
    "masamız çok kirliydi",
    "ailece çok sevdik",
    "ailece çok sevdik",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Yemek geç geldi ve sıcak değildi.",
    "yavaş ve ilgisiz",
    "çok vasattı",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "temiz ve hızlıydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "çok lezzetli",
    "ailece çok sevdik",
    "hiç hoşuma gitmedi",
    "çok rahatsız ediciydi",
    "harikaydı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "tadı berbattı",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "çok rahatsız ediciydi",
    "Yemek geç geldi ve sıcak değildi.",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "hiç hoşuma gitmedi",
    "hiç hoşuma gitmedi",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "yemek geç geldi",
    "çok lezzetli",
    "kesinlikle tekrar gelirim",
    "tadı berbattı",
    "çok lezzetli",
    "bayıldım",
    "harikaydı",
    "temiz ve hızlıydı",
    "kesinlikle tekrar gelirim",
    "çok rahatsız ediciydi",
    "harikaydı",
    "yavaş ve ilgisiz",
    "yemek geç geldi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "tadı berbattı",
    "çok vasattı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Yemek geç geldi ve sıcak değildi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "güler yüzlü hizmet",
    "güler yüzlü hizmet",
    "yavaş ve ilgisiz",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yavaş ve ilgisiz",
    "yavaş ve ilgisiz",
    "bayıldım",
    "harikaydı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yavaş ve ilgisiz",
    "fiyatlar gereksiz pahalı",
    "masamız çok kirliydi",
    "tam kıvamında",
    "hiç hoşuma gitmedi",
    "tadı berbattı",
    "bayıldım",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "fiyatlar gereksiz pahalı",
    "çok lezzetli",
    "masamız çok kirliydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "tadı berbattı",
    "tam kıvamında",
    "güler yüzlü hizmet",
    "güler yüzlü hizmet",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "yavaş ve ilgisiz",
    "Yemek geç geldi ve sıcak değildi.",
    "çok rahatsız ediciydi",
    "Ailecek çok güzel bir akşam yemeği yedik.",
    "ailece çok sevdik",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "yavaş ve ilgisiz",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "fiyatlar gereksiz pahalı",
    "tadı berbattı",
    "çok lezzetli",
    "hiç hoşuma gitmedi",
    "harikaydı",
    "yemek geç geldi",
    "yemek geç geldi",
    "çok rahatsız ediciydi",
    "bayıldım",
    "tam kıvamında",
    "fiyatlar gereksiz pahalı",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "Yemek geç geldi ve sıcak değildi.",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "güler yüzlü hizmet",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "yavaş ve ilgisiz",
    "ailece çok sevdik",
    "çok vasattı",
    "çok vasattı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "yemek geç geldi",
    "güler yüzlü hizmet",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "çok vasattı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "Servis o kadar yavaştı ki yemeğin tadı kaçtı.",
    "bayıldım",
    "çok lezzetli",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "fiyatlar gereksiz pahalı",
    "Yemeklerin sunumu ve tadı gerçekten muazzamdı.",
    "tadı berbattı",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "harikaydı",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "Garsonlar ilgisizdi ve siparişimiz unutuldu.",
    "kesinlikle tekrar gelirim",
    "Her şey dört dörtlüktü, kesinlikle tavsiye ederim.",
    "harikaydı",
    "masamız çok kirliydi",
    "yemek geç geldi",
    "Fiyat performans açısından gayet memnun ediciydi.",
    "harikaydı",
    "güler yüzlü hizmet",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "Yemek geç geldi ve sıcak değildi.",
    "çok lezzetli",
    "kesinlikle tekrar gelirim",
    "temiz ve hızlıydı",
    "Verilen paraya yazık, beklediğim gibi değildi.",
    "fiyatlar gereksiz pahalı",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi.",
    "bayıldım",
    "harikaydı",
    "hiç hoşuma gitmedi",
    "ailece çok sevdik",
    "çok rahatsız ediciydi",
    "çok rahatsız ediciydi",
    "çok rahatsız ediciydi",
    "Ortam gürültülü ve hijyen yetersizdi.",
    "yemek geç geldi",
    "hiç hoşuma gitmedi",
    "Mekan çok temizdi ve çalışanlar oldukça ilgiliydi."
    ],
    "label": [
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "positive",
        "positive",
        "negative",
        "positive",
        "negative",
        "negative",
        "negative",
        "positive",
        "positive",
        "negative",
        "negative",
        "positive",
        "negative",
        "negative",
        "negative",
        "negative",
        "positive",
        "positive",
        "negative",
        "negative",
        "negative",
        "negative",
        "positive",
        "negative",
        "positive",
        "negative",
        "positive",
        "positive",
        "negative",
        "positive",
        "positive",
        "positive",
        "negative",
        "positive",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "positive",
        "negative",
        "negative",
        "negative",
        "positive",
        "negative",
        "negative",
        "positive",
        "positive",
        "positive",
        "negative",
        "positive",
        "positive",
        "positive",
        "negative",
        "positive",
        "negative",
        "negative",
        "positive",
        "negative",
        "negative",
        "positive",
        "positive",
        "positive",
        "negative",
        "negative",
        "positive",
        "negative",
        "negative",
        "negative",
        "positive",
        "negative",
        "positive",
        "positive",
        "negative",
        "positive",
        "negative",
        "positive",
        "positive",
        "negative",
        "negative",
        "positive",
        "positive",
        "negative",
        "negative",
        "positive",
        "positive",
        "negative",
        "positive",
        "positive",
        "negative",
        "positive",
        "negative",
        "positive",
        "negative",
        "positive",
        "positive",
        "positive",
        "negative",
        "negative",
        "negative",
        "positive",
        "negative",
        "negative",
        "negative",
        "positive",
        "positive",
        "negative",
        "positive",
        "positive",
        "positive",
        "negative",
        "positive",
        "negative",
        "negative",
        "positive",
        "positive",
        "positive",
        "negative",
        "negative",
        "negative",
        "negative",
        "positive",
        "positive",
        "positive",
        "negative",
        "positive",
        "negative",
        "positive",
        "positive",
        "negative",
        "positive",
        "positive",
        "negative",
        "negative",
        "positive",
        "positive",
        "positive",
        "positive",
        "negative",
        "positive",
        "positive",
        "negative",
        "positive",
        "positive",
        "negative",
        "negative",
        "negative",
        "negative",
        "positive",
        "positive",
        "negative",
        "negative",
        "positive",
        "negative",
        "positive",
        "positive",
        "positive",
        "negative",
        "positive",
        "negative",
        "positive",
        "negative",
        "negative",
        "positive",
        "positive",
        "negative",
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "negative",
        "positive",
        "positive",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative",
        "positive",
        "positive",
        "positive",
        "negative",
        "positive",
        "negative",
        "negative",
        "positive",
        "negative",
        "negative",
        "positive",
        "positive",
        "positive",
        "positive",
        "negative",
        "negative",
        "negative",
        "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
        "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "positive",
    "positive",
    "positive",
    "negative",
    "positive",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "negative",
    "positive"
    ]
}

# %%
# metin temizleme ve preprocessing: tokenization, padding, label encoding, train test split
df=pd.DataFrame(data)

#tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df["text"])
sequences = tokenizer.texts_to_sequences(df["text"])
word_index = tokenizer.word_index

#padding process
maxlen = max(len(seq) for seq in sequences)
x= pad_sequences(sequences, maxlen = maxlen)
print(x.shape)


#label encoding
label_encoder=LabelEncoder()
y = label_encoder.fit_transform(df["label"])


#train test split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
# Out:
# (15198, 8)

# %%
# metin temsili: word_embedding : word2vec
sentences = [text.split() for text in df["text"]]
word2vec_model = Word2Vec(sentences, vector_size=50, window=5, min_count=1)

embedding_dim = 50  
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))

for word, i in word_index.items():
    if word in word2vec_model.wv:
        embedding_matrix[i] = word2vec_model.wv[word]

# %%
#modelling : build, train, test tnn modeli

model = Sequential()

#embeding
model.add(Embedding(input_dim= len(word_index) + 1, output_dim= embedding_dim, weights = [embedding_matrix], input_length=maxlen,trainable=False) )

#RNN layer
model.add(SimpleRNN(50,return_sequences=False))


#output Layer
model.add(Dense(1,activation="sigmoid"))

#complie model
model.compile(optimizer="adam" , loss="binary_crossentropy", metrics=["accuracy"])
                                                                      
#train model
model.fit(x_train,y_train,epochs=5, batch_size = 2, validation_data=(x_test,y_test))
# Out:
# Epoch 1/5
# D:\anaconda\lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 6079/6079 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - accuracy: 0.8680 - loss: 0.2411 - val_accuracy: 0.9283 - val_loss: 0.1400
# Epoch 2/5
# 6079/6079 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9433 - loss: 0.1333 - val_accuracy: 0.9385 - val_loss: 0.1003
# Epoch 3/5
# 6079/6079 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9777 - loss: 0.0833 - val_accuracy: 1.0000 - val_loss: 0.0474
# Epoch 4/5
# 6079/6079 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.9940 - loss: 0.0434 - val_accuracy: 1.0000 - val_loss: 0.0249
# Epoch 5/5
# 6079/6079 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.9994 - loss: 0.0208 - val_accuracy: 1.0000 - val_loss: 0.0105

# %%
#evaluate run model
test_loss, test_accuracy  =model.evaluate(x_test, y_test)
print(f"test loss: {test_loss}, test accuracy : {test_accuracy}")
# Out:
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0113
# test loss: 0.010473135858774185, test accuracy : 1.0

# %%
#cümle sınıflandırma çalışması
def classify_sentence(sentence):
    seq = tokenizer.texts_to_sequences([sentence])
    padded_seq = pad_sequences(seq, maxlen=maxlen)
    prediction = model.predict(padded_seq)
    predicted_class = (prediction > 0.5).astype(int)
    label = "positive" if predicted_class[0][0] == 1 else "negative"
    return label

# %%
sentence = input("Sınıflandırmak istediğiniz metni giriniz: ")
result = classify_sentence(sentence)
print(f"Sınıfı: {result}")
# Out:
# Sınıflandırmak istediğiniz metni giriniz:  her şey çok lezzetliydi, birdaha gelirim
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Sınıfı: positive
